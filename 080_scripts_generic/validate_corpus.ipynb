# %% [markdown]
# # Validating finished Shawi Corpus Files
#
# * Install & set up dependencies
# * extract schematron from RNG and transform to XSLT
# * run schematron-xslt on files

# %%
import io
import os
import requests
import pathlib
import re
import sys
import json
import pandas as pd
import linecache as lc
import shutil

from pathlib import Path
from urllib.parse import urlsplit
import saxonche
from zipfile import ZipFile
from lxml import isoschematron, etree

# %%
tmpDir = "tmp"
libDir = "lib"
os.makedirs(tmpDir, exist_ok=True)
os.makedirs(libDir, exist_ok=True)
nss = {"tei":"http://www.tei-c.org/ns/1.0"}
dataHome = ".."

# rng schema
rngSchema = dataHome + "/802_tei_odd/out/shawi_corpus.rng"
# dict rng schema
dictRngSchema = dataHome + "/802_tei_odd/out/shawi_dict.rng"
# the path to the annotated TEI transcription files
manannot = dataHome + "/010_manannot"
# the path to the dictionary
dictionary = dataHome + "/vicav_dicts/dc_shawi_eng.xml"

# include those documents in validation which have the following status in //tei:revisionDesc/@status / ignore all others
VALIDATE_DOCS_WITH_STATUS = "done"

with saxonche.PySaxonProcessor(license=False) as proc:
    print(proc.version)
    proc.set_cwd(os.path.dirname(os.path.dirname(os.path.abspath(''))))
    print(proc.cwd)
# Out:
# SaxonC-HE 12.9 from Saxonica
# Q:\basexshawi

# %%
def downloadAndStore(url, force=False):   
    #  filename of the file to be downloaded
    fn = os.path.basename(url)
    # fn w/o extension
    basename = os.path.splitext(fn)[0]
    # extension 
    ext = os.path.splitext(fn)[1]
    dlFilePath = tmpDir + "/" + fn
    if not os.path.exists(dlFilePath) and not force == True:
        payload = requests.get(url).content
        open(dlFilePath, 'wb').write(payload)
    return dlFilePath

# %%
def downloadAndUnzip(url):    
    #  filename of the file to be downloaded
    fn = os.path.basename(url)
    # fn w/o extension
    basename = os.path.splitext(fn)[0]
    # extension 
    ext = os.path.splitext(fn)[1]
    
    if ext != ".zip":
        return "not a zip archive"
    else:
        zipFilePath = downloadAndStore(url)
        # the path where the content should be extracted to
        targetPath = libDir + "/" + basename
        
        
        payload = requests.get(url).content
        open(zipFilePath, 'wb').write(payload)
        ZipFile(zipFilePath).extractall(path=targetPath)
    
    return targetPath

# %%
def transform(s, xsl, o, parameters=[]):
    # processor keeps files open on Windows and in doing so prevents moving or copying them
    try:
        with saxonche.PySaxonProcessor(license=False) as proc:
            proc.set_configuration_property("xi", "on")
            saxon = proc.new_xslt30_processor()
            for i in parameters:
                saxon.set_parameter(name=i, value=proc.make_string_value(parameters[i]))
            exec = saxon.compile_stylesheet(stylesheet_file=os.path.abspath(xsl))
            exec.apply_templates_returning_file(source_file=os.path.abspath(s), output_file=os.path.abspath(o))
            if exec.exception_occurred:
                exec.get_error_message
                #for i in range(saxon.exception_count()-1):
                print(saxon.get_error_message())
                print(os.path.abspath(s)+" - "+os.path.abspath(xsl)+" -> "+os.path.abspath(o)+" failed")
            if os.path.exists(os.path.abspath(o)):
                return o
            else: 
                print("there was an error transforming "+s+" with stylesheet "+xsl)
    except Exception as e:
        print("Python Exception during transform:", e)

# %% [markdown]
# ### Install XSL based schematron validator

# %%
_schCompiler = None
def setupSchXSLT():
    global _schCompiler
    if _schCompiler is not None:
        return _schCompiler
    schDLURL = "https://codeberg.org/SchXslt/schxslt/releases/download/v1.10.1/schxslt-1.10.1-xslt-only.zip"
    schHome = downloadAndUnzip(schDLURL)
    _schCompiler = schHome + "/schxslt-1.10.1/2.0/pipeline-for-svrl.xsl"
    if os.path.exists(_schCompiler):
        return _schCompiler
    else: 
        print("error: something went wrong, cannot locate file '" + schCompiler + "'")

# %%
setupSchXSLT()
# Out:
# 'lib/schxslt-1.10.1-xslt-only/schxslt-1.10.1/2.0/pipeline-for-svrl.xsl'

# %% [markdown]
# ## Prepare rng2sch stylesheet
#
# Returns path to the xsl that extracts schematron form the RelaxNG schema.
# This should only run once as the file gets locked (by saxon) and so further attempts to pring it to the correct location will fail.

# %%
_rng2sch = None 
def setupRNG2Sch():
    global _rng2sch
    if _rng2sch is not None:
        return _rng2sch
    RNG2SchtrDL = "https://raw.githubusercontent.com/Schematron/schematron/master/trunk/converters/code/ToSchematron/ExtractSchFromRNG.xsl"
    dltmp = downloadAndStore(RNG2SchtrDL)
    # tweak XSLT 
    with open(dltmp, encoding='utf-8') as inputfile:
        lines = inputfile.read()
    lines = lines.replace( 'http://www.ascc.net/xml/schematron','http://purl.oclc.org/dsdl/schematron/')
    lines = lines.replace( '<sch:schema','<sch:schema queryBinding="xslt2"')
    
    with open(dltmp, 'w', encoding='utf-8') as file:
        file.writelines(lines)
    _rng2sch = libDir+"/"+os.path.basename(dltmp)
    os.replace(dltmp, _rng2sch)
    if os.path.exists(_rng2sch):
        return _rng2sch
    else:
        print("error: something went wrong, cannot locate file '" + newPath + "'")

# %%
setupRNG2Sch()
# Out:
# 'lib/ExtractSchFromRNG.xsl'

# %% [markdown]
# ## Extract schematron from RNG and transform to XSLT

# %%
def extractSchematron(rng):
    """extracts a schematron document embedded in an rng schema"""
    print("extracting Schematron document from "+rng)
    rng2sch = setupRNG2Sch()
    sch = tmpDir + "/" + os.path.basename(rng) + ".sch"
    if not os.path.exists(sch):
        transform(rng, rng2sch, sch)
    return sch

# %%
def compileSchematron(sch):
    """compiles a schematron document to an XSLT stylesheet"""
    outputPath = tmpDir + "/" + os.path.basename(sch) + ".xsl"
    schCompiler = setupSchXSLT()
    transform(sch, schCompiler, outputPath)
    
    if os.path.exists(outputPath):
        print(outputPath)
        return outputPath
    else: 
        print("error: something went wrong, cannot locate file '" + outputPath + "'")

# %%
sch = extractSchematron(rngSchema)
schXSL = compileSchematron(sch)
dictSch = extractSchematron(dictRngSchema)
dictSchXSL = compileSchematron(dictSch)
# Out:
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# tmp/shawi_corpus.rng.sch.xsl
# extracting Schematron document from ../802_tei_odd/out/shawi_dict.rng
# tmp/shawi_dict.rng.sch.xsl

# %% [markdown]
# ## Run schematron and relaxNG on files

# %%
validationErrors = []
ignoredFiles = []

# %%
def schValidate(schXSL, path):
    """validates a document (at path) against an XSL compiled schematron schema (at schXSL)"""
    errs = []
    out = tmpDir + "/validationReports/" + os.path.basename(path)
    try:
        transform(path, schXSL, out)

    except saxonche.PySaxonApiError as e:
        # We swallow parsing errors here as they should have been reported by lxml already
        print("an error occured while running schValidate on "+path)
        return []
    
    report = etree.parse(out)
    successfulReport = report.findall("{http://purl.oclc.org/dsdl/svrl}successful-report")
    failedAssert = report.findall("{http://purl.oclc.org/dsdl/svrl}failed-assert")
    doc = etree.parse(path)
    for s in successfulReport + failedAssert:
        XPath = s.attrib['location'].replace('Q{http://www.tei-c.org/ns/1.0}','tei:').replace('Q{}','')
        # DEBUG
        node = doc.xpath(XPath, namespaces=nss)[0]
        if type(node) is etree._ElementUnicodeResult:
            elt = node.getparent()
        else:
            elt = node

        msg = s.find("{http://purl.oclc.org/dsdl/svrl}text").text

        errObj = {
            "type" : "error",
            "message":  msg,
            "line" : elt.sourceline,
            "source": path,
            "location": XPath,
            #"text": elt.text, #checking text values (for @lemmaRef)
            "stage": "schematron",
            "exceptionType": str(s.tag).replace("{http://purl.oclc.org/dsdl/svrl}",""),
        }
        
        errs.append(errObj)
    return errs

# %%
def validate(path, rngSchema, schematronSchemaXSL):
    """Validate a document against the rngSchema. Returns a list of dicts of which each one represents a validation (or parsing) error."""
    validationErrors = []
    shutil.copyfile(sch, '../802_tei_odd/out/'+os.path.basename(sch)) #copy file from tmp folder into odd folder to be able to git it
    try:
        doc = etree.parse(path)
    
        # relaxng validation
        relaxng_doc = etree.parse(rngSchema)
        relaxng = etree.RelaxNG(relaxng_doc)
        relaxng.assertValid(doc)
        
        # schematron validation
        schErrs = schValidate(schematronSchemaXSL, path)
        if len(schErrs) >= 1:
            validationErrors = validationErrors + schErrs
    
    except etree.XMLSyntaxError as e:
        valErrObj = {
            "type" : "error",
            "message": str(e), 
            "line": e.lineno,
            "source": path, 
            "location": "n/a",
            "stage" : "parsing", 
            "exceptionType": type(e).__name__
        }
        return valErrObj
        
    except etree.DocumentInvalid as e:
        for error in e.error_log:
            # we ignore rng errors about @schemaLocation since 
            # that is needed for validation in the TEI-enricher
            if error.message != "Invalid attribute schemaLocation for element TEI":
                location = "n/a" if error.path is None else error.path
                valErrObj = {
                    "type" : "error",
                    "message": error.message, 
                    "line": error.line, 
                    "source": path, 
                    "location": location,
                    "stage" : "relaxng", 
                    "exceptionType": type(e).__name__
                }
                # DEBUG
                print(valErrObj)
                validationErrors.append(valErrObj)
        
        # if the document is invalid against the RNG, we still want to run schematron against it
        schErrs = schValidate(schematronSchemaXSL, path)
        if len(schErrs) >= 1:
            validationErrors = validationErrors + schErrs
        
        
    
    return validationErrors

# %%
def docStatus(path):
    """returns the status of the document at path; if the document can't be parsed, it returns a dict with the error"""
    try:
        doc = etree.parse(path)
        revisionDesc = doc.xpath("/tei:TEI/tei:teiHeader/tei:revisionDesc", namespaces=nss)[0]
        status = revisionDesc.attrib['status']
        return status
    # report documents which are not well-formed
    except etree.XMLSyntaxError as e:
        print(e)

# %%
def validateAndAppend(filepath, rngSchema, schXSL):
    global validationErrors, ignoredFiles
    print("validating " + filepath)
    results = validate(filepath, rngSchema, schXSL)
    print(results)
    len(results)
    if type(results) is list:
        res_errs = filter(lambda x: x['type'] == "error", results)
        res_ignored = filter(lambda x: x['type'] == "ignored", results)
        validationErrors = validationErrors + list(res_errs)
        print(f"{len(list(res_errs))} found / {len(validationErrors)} in total")
    elif type(results) is dict:
        if results['type'] == "ignored":
            ignoredFiles.append(results)
    else:
        print("unknown result type")
        print(results)

# %%
# preprorcess and remove all stubs
# validateAndAppend(dictionary, dictRngSchema, dictSchXSL)

# %%
for i in os.scandir(manannot):
    if i.name.startswith('Urfa') and i.name.endswith('.xml') and i.is_file():
        filename = os.path.basename(i)
        filepath = manannot + "/" + filename
        status = docStatus(filepath)
        print(filename, status)
        
        # if the document is not finished yet (//tei:revisionDesc/@status != DOCSTATUS_DONE), just ignore it
        if type(status) is str and status != VALIDATE_DOCS_WITH_STATUS:
            ignoredFiles.append({
                "source" : filepath,
                "type" : "ignored",
                "status": status
            })
        # if the document couldn't be parsed, docStatus() returns a dict 
        # with some error information which is appended to the list of 
        # validation errors
        elif type(status) is dict and status["type"] == "error":
            validationErrors.append(status) 
        
        # … otherwise try to validate the document
        else:
            validateAndAppend(filepath, rngSchema, schXSL)
# Out:
# Urfa-000_Namrud-Harran-2001.xml done
# validating ../010_manannot/Urfa-000_Namrud-Harran-2001.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 300, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 331, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 370, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 402, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 443, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 490, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 517, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 544, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 571, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 606, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 634, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 688, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[12]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', ...
# 0 found / 34 in total
# Urfa-002a_Joke_about_a_tribe.xml done
# validating ../010_manannot/Urfa-002a_Joke_about_a_tribe.xml
# {'type': 'error', 'message': 'Did not expect element vocal there', 'line': 398, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/*/*[2]/*[2]/*/*[7]/*[1]/*[18]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# {'type': 'error', 'message': 'Element u has extra content: vocal', 'line': 398, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/*/*[2]/*[2]/*/*[7]/*[1]/*[18]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Did not expect element vocal there', 'line': 398, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/*/*[2]/*[2]/*/*[7]/*[1]/*[18]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'Element u has extra content: vocal', 'line': 398, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/*/*[2]/*[2]/*/*[7]/*[1]/*[18]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 210, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 261, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 285, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 341, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 373, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 404, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 446, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 513, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 44 in total
# Urfa-002b_Blood_feud_in_the_past.xml generated
# Urfa-002c_The_incomplete_meal.xml done
# validating ../010_manannot/Urfa-002c_The_incomplete_meal.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 213, 'source': '../010_manannot/Urfa-002c_The_incomplete_meal.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 246, 'source': '../010_manannot/Urfa-002c_The_incomplete_meal.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 298, 'source': '../010_manannot/Urfa-002c_The_incomplete_meal.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 332, 'source': '../010_manannot/Urfa-002c_The_incomplete_meal.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 391, 'source': '../010_manannot/Urfa-002c_The_incomplete_meal.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 447, 'source': '../010_manannot/Urfa-002c_The_incomplete_meal.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 481, 'source': '../010_manannot/Urfa-002c_The_incomplete_meal.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 524, 'source': '../010_manannot/Urfa-002c_The_incomplete_meal.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 566, 'source': '../010_manannot/Urfa-002c_The_incomplete_meal.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 607, 'source': '../010_manannot/Urfa-002c_The_incomplete_meal.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 54 in total
# Urfa-002d_The_bull_in_the_jar.xml done
# validating ../010_manannot/Urfa-002d_The_bull_in_the_jar.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 212, 'source': '../010_manannot/Urfa-002d_The_bull_in_the_jar.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 259, 'source': '../010_manannot/Urfa-002d_The_bull_in_the_jar.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 307, 'source': '../010_manannot/Urfa-002d_The_bull_in_the_jar.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 344, 'source': '../010_manannot/Urfa-002d_The_bull_in_the_jar.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 379, 'source': '../010_manannot/Urfa-002d_The_bull_in_the_jar.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 419, 'source': '../010_manannot/Urfa-002d_The_bull_in_the_jar.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 459, 'source': '../010_manannot/Urfa-002d_The_bull_in_the_jar.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 61 in total
# Urfa-011_Cemetry-Harran-2010.xml done
# validating ../010_manannot/Urfa-011_Cemetry-Harran-2010.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 298, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 329, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 380, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 435, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 517, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 575, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 646, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 730, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 808, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 871, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 914, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 995, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[12]/tei:spanGrp[1]/tei:span[1]', 'stage': ' ...
# 0 found / 81 in total
# Urfa-012_Lentils-Harran-2010.xml done
# validating ../010_manannot/Urfa-012_Lentils-Harran-2010.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 292, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 357, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 427, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 499, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 563, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 624, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 680, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 726, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 783, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 853, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 907, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 963, 'source': '../010_manannot/Urfa-012_Lentils-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[12]/tei:spanGrp[1]/tei:span[1]', 'stage': ' ...
# 0 found / 98 in total
# Urfa-014_Village_of_Qoran-Harran-2010.xml done
# validating ../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 278, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 327, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 373, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 431, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 484, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 529, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 555, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 614, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 677, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 746, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 824, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 872, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'lo ...
# 0 found / 119 in total
# Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml done
# validating ../010_manannot/Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 245, 'source': '../010_manannot/Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 303, 'source': '../010_manannot/Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 365, 'source': '../010_manannot/Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 122 in total
# Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml done
# validating ../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 336, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 384, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 438, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 498, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 550, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 616, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 654, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 733, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 776, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 845, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 906, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span sho ...
# 0 found / 146 in total
# Urfa-027_Cultivation-Harran-2010.xml done
# validating ../010_manannot/Urfa-027_Cultivation-Harran-2010.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 282, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 325, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 366, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 396, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 413, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 448, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 479, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 503, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 537, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 576, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 603, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 633, 'source': '../010_manannot/Urfa-027_Cultivation-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei ...
# 0 found / 169 in total
# Urfa-029_Smoking-Harran-2010.xml done
# validating ../010_manannot/Urfa-029_Smoking-Harran-2010.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 269, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 310, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 350, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 394, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 447, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 521, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 550, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 608, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 646, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 697, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 741, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 782, 'source': '../010_manannot/Urfa-029_Smoking-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[12]/tei:spanGrp[1]/tei:span[1]', 'stage': ' ...
# 0 found / 183 in total
# Urfa-032_Ali-Harran-2010.xml done
# validating ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 422, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 462, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 496, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 529, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 566, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 598, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 625, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 673, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 719, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 746, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 789, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 819, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[12]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'},  ...
# 0 found / 248 in total
# Urfa-033_Sheikh_Nifil-Harran-2010.xml done
# validating ../010_manannot/Urfa-033_Sheikh_Nifil-Harran-2010.xml
# ...
# 0 found / 1805 in total
# Urfa-175_Bastig-Harran-2014.xml done
# validating ../010_manannot/Urfa-175_Bastig-Harran-2014.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 294, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 320, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 360, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 381, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 416, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 441, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 466, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 506, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 544, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 570, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 606, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 641, 'source': '../010_manannot/Urfa-175_Bastig-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[12]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', ...
# 0 found / 1830 in total
# Urfa-176_Condolences-Harran-2014.xml done
# validating ../010_manannot/Urfa-176_Condolences-Harran-2014.xml
# [{'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 351, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 389, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 416, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 452, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 479, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 518, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 542, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 577, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 612, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 647, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 671, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 701, 'source': '../010_manannot/Urfa-176_Condolences-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei ...
# 0 found / 1868 in total
# Urfa-177_Wedding_in_Former_Times-Harran-2014.xml done
# validating ../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml
# {'type': 'error', 'message': 'Did not expect text in element u content', 'line': 926, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/*/*[2]/*[2]/*/*[6]/*[1]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# {'type': 'error', 'message': 'Element u has extra content: text', 'line': 926, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/*/*[2]/*[2]/*/*[6]/*[1]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Did not expect text in element u content', 'line': 926, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/*/*[2]/*[2]/*/*[6]/*[1]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'Element u has extra content: text', 'line': 926, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/*/*[2]/*[2]/*/*[6]/*[1]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 829, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 861, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 901, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 922, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 950, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 985, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 1006, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 1025, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 1058, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 1081, 'source': '../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage' ...
# 0 found / 2038 in total
# Urfa-179_Grandfather-Harran-2014.xml generated
# Urfa-183_Policeman_and_Carp-Harran-2014.xml draft
# Urfa-184_Evil_Eye-Harran-2014.xml draft
# Urfa-187_Two_Women_and_Fridge-Harran-2015.xml draft
# Urfa-188_Shepherd-Harran-2015.xml generated
# Urfa-189_Wanted_to_Marry-Harran.xml generated
# Urfa-190_ill_Blind_Mother-Harran-2015.xml generated
# Urfa-191_Kurd_and_Two_Wives-Harran-2015.xml generated
# Urfa-192_Who_chooses_a_horse-Harran.xml generated
# Urfa-193_Priapism-Harran-2015.xml generated
# Urfa-194_Afraid_of_Dogs-Harran-2017.xml generated
# Urfa-195_Best_and_Worst_Part_of_the_Sheep-Harran-2017.xml generated
# Urfa-201_Story_of_Cigkofte-Harran-2017.xml generated
# Urfa-202_Al-Shukwa-Harran-2017.xml generated
# Urfa-203_Tattooing-Harran-2017.xml generated
# Urfa-352_Washing_Clothes-Harran-2021.xml generated
# Urfa-355_Threshing_wheat_in_former_times.xml generated
# Urfa-428_How_not_to_get_married_to_an_old_man.xml generated
# Urfa-467_The_big_earthquake_of_February_2023.xml generated

# %%
# validationErrors

# %%
def make_clickable(source, line=None):
    link = source.replace('../','https://github.com/acdh-oeaw/shawi-data/tree/main/')
    if line:
        return f'<a href="{link}#L{line}">{source}</a>'
    else:
        return f'<a href="{link}">{source}</a>'

# %%
if len(ignoredFiles) > 0:
    df_ignored = pd.DataFrame(data=ignoredFiles).T
    df_ignored = df_ignored.transpose()
    df_ignored
    ignoredReport = "tmp/ignoredFiles.html"
    df_ignored['link'] = df_ignored.apply(lambda x: make_clickable(x['source']), axis=1)

    with open(ignoredReport, 'w', encoding='utf-8') as f:
        f.write(df_ignored.to_html(render_links=True, escape=False))

# %%
if len(validationErrors) > 0:
    df_err = pd.DataFrame(data=validationErrors).T
    df_err = df_err.transpose()
    df_err
    print(f"found {len(validationErrors)} validation errors")
    #df_err = df_err[df_err["message"].str.contains("@lemmaRef is required when xml:lang is 'ar-acm")==False]
    #df_err = df_err[df_err["message"].str.contains("There is no entry in the dictionary for the")==True]
    errorReport = "tmp/validationReport.html"
    df_err['link'] = df_err.apply(lambda x: make_clickable(x['source'], x['line']), axis=1)
    with open(errorReport, 'w', encoding='utf-8') as f:
        f.write(df_err.to_html(render_links=True, escape=False))
# Out:
# found 2038 validation errors

# %%
df_err
# Out:
#        type                                            message  line  \
# 0     error  target of span should point at xml:id of paren...   300
# 1     error  target of span should point at xml:id of paren...   331
# 2     error  target of span should point at xml:id of paren...   370
# 3     error  target of span should point at xml:id of paren...   402
# 4     error  target of span should point at xml:id of paren...   443
# ...     ...                                                ...   ...
# 2033  error  target of span should point at xml:id of paren...  4849
# 2034  error  target of span should point at xml:id of paren...  4893
# 2035  error  target of span should point at xml:id of paren...  4961
# 2036  error  The 'who' attribute of u must point to a perso...  1254
# 2037  error  The 'who' attribute of u must point to a perso...  1425
#
#                                                  source  \
# 0       ../010_manannot/Urfa-000_Namrud-Harran-2001.xml
# 1       ../010_manannot/Urfa-000_Namrud-Harran-2001.xml
# 2       ../010_manannot/Urfa-000_Namrud-Harran-2001.xml
# 3       ../010_manannot/Urfa-000_Namrud-Harran-2001.xml
# 4       ../010_manannot/Urfa-000_Namrud-Harran-2001.xml
# ...                                                 ...
# 2033  ../010_manannot/Urfa-177_Wedding_in_Former_Tim...
# 2034  ../010_manannot/Urfa-177_Wedding_in_Former_Tim...
# 2035  ../010_manannot/Urfa-177_Wedding_in_Former_Tim...
# 2036  ../010_manannot/Urfa-177_Wedding_in_Former_Tim...
# 2037  ../010_manannot/Urfa-177_Wedding_in_Former_Tim...
#
#                                                location       stage  \
# 0     /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 1     /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 2     /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 3     /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 4     /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# ...                                                 ...         ...
# 2033  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 2034  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 2035  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 2036  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 2037  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
#
#       exceptionType                                               link
# 0     failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 1     failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 2     failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 3     failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 4     failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# ...             ...                                                ...
# 2033  failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 2034  failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 2035  failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 2036  failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 2037  failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
#
# [2038 rows x 8 columns]
