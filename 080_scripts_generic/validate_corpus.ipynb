# %% [markdown]
# # Validating finished Shawi Corpus Files
#
# * Install & set up dependencies
# * extract schematron from RNG and transform to XSLT
# * run schematron-xslt on files

# %%
import io
import os
import requests
import pathlib
import re
import sys
import json
import pandas as pd
import linecache as lc
import shutil

from pathlib import Path
from urllib.parse import urlsplit
import saxonche
from zipfile import ZipFile
from lxml import isoschematron, etree

# %%
tmpDir = "tmp"
libDir = "lib"
os.makedirs(tmpDir, exist_ok=True)
os.makedirs(libDir, exist_ok=True)
nss = {"tei":"http://www.tei-c.org/ns/1.0"}
dataHome = ".."

# rng schema
rngSchema = dataHome + "/802_tei_odd/out/shawi_corpus.rng"
# the path to the annotated TEI transcription files
manannot = dataHome + "/010_manannot"

# include those documents in validation which have the following status in //tei:revisionDesc/@status / ignore all others
VALIDATE_DOCS_WITH_STATUS = "done"

with saxonche.PySaxonProcessor(license=False) as proc:
# SaxonC 1.2.1 Python has many known bugs but isn't maintained anymore
# Many of the documented API specs are not working
    print(proc.version)
    proc.set_cwd(os.path.dirname(os.path.dirname(os.path.abspath(''))))
    print(proc.cwd)
# Out:
# SaxonC-HE 12.5 from Saxonica
# Q:\basexshawi

# %%
def downloadAndStore(url, force=False):   
    #  filename of the file to be downloaded
    fn = os.path.basename(url)
    # fn w/o extension
    basename = os.path.splitext(fn)[0]
    # extension 
    ext = os.path.splitext(fn)[1]
    dlFilePath = tmpDir + "/" + fn
    if not os.path.exists(dlFilePath) and not force == True:
        payload = requests.get(url).content
        open(dlFilePath, 'wb').write(payload)
    return dlFilePath

# %%
def downloadAndUnzip(url):    
    #  filename of the file to be downloaded
    fn = os.path.basename(url)
    # fn w/o extension
    basename = os.path.splitext(fn)[0]
    # extension 
    ext = os.path.splitext(fn)[1]
    
    if ext != ".zip":
        return "not a zip archive"
    else:
        zipFilePath = downloadAndStore(url)
        # the path where the content should be extracted to
        targetPath = libDir + "/" + basename
        
        
        payload = requests.get(url).content
        open(zipFilePath, 'wb').write(payload)
        ZipFile(zipFilePath).extractall(path=targetPath)
    
    return targetPath

# %% [markdown]
# ### Install XSL based schematron validator

# %%
_schCompiler = None
def setupSchXSLT():
    global _schCompiler
    if _schCompiler is not None:
        return _schCompiler
    schDLURL = "https://codeberg.org/SchXslt/schxslt/releases/download/v1.10.1/schxslt-1.10.1-xslt-only.zip"
    schHome = downloadAndUnzip(schDLURL)
    _schCompiler = schHome + "/schxslt-1.10.1/2.0/pipeline-for-svrl.xsl"
    if os.path.exists(_schCompiler):
        return _schCompiler
    else: 
        print("error: something went wrong, cannot locate file '" + schCompiler + "'")

# %%
setupSchXSLT()
# Out:
# 'lib/schxslt-1.10.1-xslt-only/schxslt-1.10.1/2.0/pipeline-for-svrl.xsl'

# %%
def transform(s, xsl, o, parameters=[]):
    # processor keeps files open on Windows and in doing so prevents moving or copying them
    try:
        with saxonche.PySaxonProcessor(license=False) as proc:
            proc.set_configuration_property("xi", "on")
            saxon = proc.new_xslt30_processor()
            for i in parameters:
                saxon.set_parameter(name=i, value=proc.make_string_value(parameters[i]))
            exec = saxon.compile_stylesheet(stylesheet_file=os.path.abspath(xsl))
            exec.apply_templates_returning_file(source_file=os.path.abspath(s), output_file=os.path.abspath(o))
            if exec.exception_occurred:
                exec.get_error_message
                #for i in range(saxon.exception_count()-1):
                print(saxon.get_error_message())
                print(os.path.abspath(s)+" - "+os.path.abspath(xsl)+" -> "+os.path.abspath(o)+" failed")
            if os.path.exists(os.path.abspath(o)):
                return o
            else: 
                print("there was an error transforming "+s+" with stylesheet "+xsl)
    except Exception as e:
        print("Python Exception during transform:", e)

# %%
def extractSchematron(rng):
    """extracts a schematron document embedded in an rng schema"""
    print("extracting Schematron document from "+rng)
    rng2sch = setupRNG2Sch()
    sch = tmpDir + "/" + os.path.basename(rng) + ".sch"
    if not os.path.exists(sch):
        transform(rng, rng2sch, sch)
    return sch

# %%
def compileSchematron(sch):
    """compiles a schematron document to an XSLT stylesheet"""
    outputPath = tmpDir + "/" + os.path.basename(sch) + ".xsl"
    schCompiler = setupSchXSLT()
    transform(sch, schCompiler, outputPath)
    
    if os.path.exists(outputPath):
        return outputPath
    else: 
        print("error: something went wrong, cannot locate file '" + outputPath + "'")

# %% [markdown]
# ## Prepare rng2sch stylesheet
#
# Returns path to the xsl that extracts schematron form the RelaxNG schema.
# This should only run once as the file gets locked (by saxon) and so further attempts to pring it to the correct location will fail.

# %%
_rng2sch = None 
def setupRNG2Sch():
    global _rng2sch
    if _rng2sch is not None:
        return _rng2sch
    RNG2SchtrDL = "https://raw.githubusercontent.com/Schematron/schematron/master/trunk/converters/code/ToSchematron/ExtractSchFromRNG.xsl"
    dltmp = downloadAndStore(RNG2SchtrDL)
    # tweak XSLT 
    with open(dltmp, encoding='utf-8') as inputfile:
        lines = inputfile.read()
    lines = lines.replace( 'http://www.ascc.net/xml/schematron','http://purl.oclc.org/dsdl/schematron/')
    lines = lines.replace( '<sch:schema','<sch:schema queryBinding="xslt2"')
    
    with open(dltmp, 'w', encoding='utf-8') as file:
        file.writelines(lines)
    _rng2sch = libDir+"/"+os.path.basename(dltmp)
    os.replace(dltmp, _rng2sch)
    if os.path.exists(_rng2sch):
        return _rng2sch
    else:
        print("error: something went wrong, cannot locate file '" + newPath + "'")

# %%
setupRNG2Sch()
# Out:
# 'lib/ExtractSchFromRNG.xsl'

# %%
def schValidate(sch, path):
    """validates a document (at path) against schematron schema (at sch)"""
    errs = []
    out = tmpDir + "/validationReports/" + os.path.basename(path)
    xsl = compileSchematron(sch)
    try:
        transform(path, xsl, out)

    except saxonche.PySaxonApiError as e:
        # We swallow parsing errors here as they should have been reported by lxml already
        print("an error occured while running schValidate on "+path)
        return []
    
    report = etree.parse(out)
    successfulReport = report.findall("{http://purl.oclc.org/dsdl/svrl}successful-report")
    failedAssert = report.findall("{http://purl.oclc.org/dsdl/svrl}failed-assert")
    doc = etree.parse(path)
    for s in successfulReport + failedAssert:
        XPath = s.attrib['location'].replace('Q{http://www.tei-c.org/ns/1.0}','tei:').replace('Q{}','')
        # DEBUG
        node = doc.xpath(XPath, namespaces=nss)[0]
        if type(node) is etree._ElementUnicodeResult:
            elt = node.getparent()
        else:
            elt = node

        msg = s.find("{http://purl.oclc.org/dsdl/svrl}text").text

        errObj = {
            "type" : "error",
            "message":  msg,
            "line" : elt.sourceline,
            "source": path,
            "location": XPath,
            #"text": elt.text, #checking text values (for @lemmaRef)
            "stage": "schematron",
            "exceptionType": str(s.tag).replace("{http://purl.oclc.org/dsdl/svrl}",""),
        }
        
        errs.append(errObj)
    return errs

# %%
def validate(path, rngSchema):
    """Validate a document against the rngSchema. Returns a list of dicts of which each one represents a validation (or parsing) error."""
    validationErrors = []
    sch = extractSchematron(rngSchema)
    shutil.copyfile(sch, '../802_tei_odd/out/'+os.path.basename(sch)) #copy file from tmp folder into odd folder to be able to git it
    try:
        doc = etree.parse(path)
    
        # relaxng validation
        relaxng_doc = etree.parse(rngSchema)
        relaxng = etree.RelaxNG(relaxng_doc)
        relaxng.assertValid(doc)
        
        # schematron validation
        schErrs = schValidate(sch, path)
        if len(schErrs) >= 1:
            validationErrors = validationErrors + schErrs
    
    except etree.XMLSyntaxError as e:
        valErrObj = {
            "type" : "error",
            "message": str(e), 
            "line": e.lineno,
            "source": path, 
            "location": "n/a",
            "stage" : "parsing", 
            "exceptionType": type(e).__name__
        }
        return valErrObj
        
    except etree.DocumentInvalid as e:
        for error in e.error_log:
            # we ignore rng errors about @schemaLocation since 
            # that is needed for validation in the TEI-enricher
            if error.message != "Invalid attribute schemaLocation for element TEI":
                location = "n/a" if error.path is None else error.path
                valErrObj = {
                    "type" : "error",
                    "message": error.message, 
                    "line": error.line, 
                    "source": path, 
                    "location": location,
                    "stage" : "relaxng", 
                    "exceptionType": type(e).__name__
                }
                # DEBUG
                print(valErrObj)
                validationErrors.append(valErrObj)
        
        # if the document is invalid against the RNG, we still want to run schematron against it
        schErrs = schValidate(sch, path)
        if len(schErrs) >= 1:
            validationErrors = validationErrors + schErrs
        
        
    
    return validationErrors

# %%
validationErrors = []
ignoredFiles = []

# %%
def docStatus(path):
    """returns the status of the document at path; if the document can't be parsed, it returns a dict with the error"""
    try:
        doc = etree.parse(path)
        revisionDesc = doc.xpath("/tei:TEI/tei:teiHeader/tei:revisionDesc", namespaces=nss)[0]
        status = revisionDesc.attrib['status']
        return status
    # report documents which are not well-formed
    except etree.XMLSyntaxError as e:
        print(e)

# %%
for i in os.scandir(manannot):
    if i.name.startswith('Urfa') and i.name.endswith('.xml') and i.is_file():
        filename = os.path.basename(i)
        filepath = manannot + "/" + filename
        status = docStatus(filepath)
        print(filename, status)
        
        # if the document is not finished yet (//tei:revisionDesc/@status != DOCSTATUS_DONE), just ignore it
        if type(status) is str and status != VALIDATE_DOCS_WITH_STATUS:
            ignoredFiles.append({
                "source" : filepath,
                "type" : "ignored",
                "status": status
            })
        # if the document couldn't be parsed, docStatus() returns a dict 
        # with some error information which is appended to the list of 
        # validation errors
        elif type(status) is dict and status["type"] == "error":
            validationErrors.append(status) 
        
        # … otherwise try to validate the document
        else:
            print("validating " + filepath)
            results = validate(filepath, rngSchema)
            print(results)
            len(results)
            if type(results) is list:
                res_errs = filter(lambda x: x['type'] == "error", results)
                res_ignored = filter(lambda x: x['type'] == "ignored", results)
                validationErrors = validationErrors + list(res_errs)
                print(f"{len(list(res_errs))} found / {len(validationErrors)} in total")
            elif type(results) is dict:
                if results['type'] == "ignored":
                    ignoredFiles.append(results)
            else:
                print("unknown result type")
                print(results)
# Out:
# Urfa-000_Namrud-Harran-2001.xml done
# validating ../010_manannot/Urfa-000_Namrud-Harran-2001.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 328, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[4]/tei:u[1]/tei:w[15]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1017, 'source': '../010_manannot/Urfa-000_Namrud-Harran-2001.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[22]/tei:u[1]/tei:w[11]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 2 in total
# Urfa-002a_Joke_about_a_tribe.xml done
# validating ../010_manannot/Urfa-002a_Joke_about_a_tribe.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 399, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[6]/tei:u[1]/tei:w[17]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 469, 'source': '../010_manannot/Urfa-002a_Joke_about_a_tribe.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[8]/tei:u[1]/tei:w[8]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 4 in total
# Urfa-002b_Blood_feud_in_the_past.xml generated
# Urfa-002c_The_incomplete_meal.xml done
# validating ../010_manannot/Urfa-002c_The_incomplete_meal.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 4 in total
# Urfa-002d_The_bull_in_the_jar.xml done
# validating ../010_manannot/Urfa-002d_The_bull_in_the_jar.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 4 in total
# Urfa-011_Cemetry-Harran-2010.xml done
# validating ../010_manannot/Urfa-011_Cemetry-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Did not expect element div there', 'line': 234, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[2]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# {'type': 'error', 'message': 'Element div has extra content: div', 'line': 234, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[2]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Did not expect element div there', 'line': 234, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[2]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'Element div has extra content: div', 'line': 234, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[2]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 238, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[1]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 305, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 336, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[3]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 387, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 442, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 524, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 582, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 653, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 737, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 815, 'source': '../010_manannot/Urfa-011_Cemetry-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[10]/tei:spanGrp[1]/tei:span[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': 'target of span should point at xml:id of parent annotationBlock element', 'line': 878, 'source': '../010_manannot/Urfa-011_Cemetry-H ...
# 0 found / 27 in total
# Urfa-012_Lentils-Harran-2010.xml done
# validating ../010_manannot/Urfa-012_Lentils-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 27 in total
# Urfa-014_Village_of_Qoran-Harran-2010.xml done
# validating ../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 415, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[5]/tei:u[1]/tei:w[16]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1249, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[18]/tei:u[1]/tei:w[35]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 29 in total
# Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml done
# validating ../010_manannot/Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 29 in total
# Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml done
# validating ../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 795, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[10]/tei:u[1]/tei:w[31]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 908, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[12]/tei:u[1]/tei:w[22]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 31 in total
# Urfa-027_Cultivation-Harran-2010.xml done
# validating ../010_manannot/Urfa-027_Cultivation-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 31 in total
# Urfa-029_Smoking-Harran-2010.xml done
# validating ../010_manannot/Urfa-029_Smoking-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 31 in total
# Urfa-032_Ali-Harran-2010.xml done
# validating ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 264, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[1]/tei:u[1]/tei:phr[1]/tei:w[3]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 315, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[2]/tei:u[1]/tei:w[14]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 454, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[6]/tei:u[1]/tei:w[6]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 784, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[15]/tei:u[1]/tei:w[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 864, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[17]/tei:u[1]/tei:w[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1621, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[38]/tei:u[1]/tei:w[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1648, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[39]/tei:u[1]/tei:w[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1673, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[39]/tei:u[2]/tei:w[2]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1978, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[48]/tei:u[1]/tei:w[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 2304, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[57]/tei:u[1]/tei:w[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 41 in total
# Urfa-033_Sheikh_Nifil-Harran-2010.xml done
# validating ../010_manannot/Urfa-033_Sheikh_Nifil-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 371, 'source': '../010_manannot/Urfa-033_Sheikh_Nifil-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[4]/tei:u[1]/tei:w[5]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 541, 'source': '../010_manannot/Urfa-033_Sheikh_Nifil-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[7]/tei:u[1]/tei:w[9]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 611, 'source': '../010_manannot/Urfa-033_Sheikh_Nifil-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[8]/tei:u[1]/tei:w[20]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 967, 'source': '../010_manannot/Urfa-033_Sheikh_Nifil-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[14]/tei:u[1]/tei:w[30]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 45 in total
# Urfa-034_Liquorice-Harran-2010.xml done
# validating ../010_manannot/Urfa-034_Liquorice-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 226, 'source': '../010_manannot/Urfa-034_Liquorice-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[1]/tei:u[3]/tei:w[21]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 46 in total
# Urfa-042_Hospitality-Harran-2010.xml done
# validating ../010_manannot/Urfa-042_Hospitality-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 238, 'source': '../010_manannot/Urfa-042_Hospitality-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[1]/tei:u[1]/tei:w[23]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 1126, 'source': '../010_manannot/Urfa-042_Hospitality-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[17]/tei:u[1]/tei:w[40]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 2029, 'source': '../010_manannot/Urfa-042_Hospitality-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[32]/tei:u[1]/tei:w[21]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 49 in total
# Urfa-043_Truffle-Harran-2010.xml done
# validating ../010_manannot/Urfa-043_Truffle-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 294, 'source': '../010_manannot/Urfa-043_Truffle-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[2]/tei:u[1]/tei:w[44]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 50 in total
# Urfa-044_Sacks-Harran-2010.xml done
# validating ../010_manannot/Urfa-044_Sacks-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 356, 'source': '../010_manannot/Urfa-044_Sacks-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[4]/tei:u[1]/tei:w[8]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 627, 'source': '../010_manannot/Urfa-044_Sacks-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[9]/tei:u[1]/tei:w[10]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 52 in total
# Urfa-045_Gamra_Dariba-Harran-2010.xml done
# validating ../010_manannot/Urfa-045_Gamra_Dariba-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 52 in total
# Urfa-046_Game_Xwetime-Harran-2010.xml done
# validating ../010_manannot/Urfa-046_Game_Xwetime-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 395, 'source': '../010_manannot/Urfa-046_Game_Xwetime-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[5]/tei:u[1]/tei:w[8]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1070, 'source': '../010_manannot/Urfa-046_Game_Xwetime-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[19]/tei:u[1]/tei:w[5]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 54 in total
# Urfa-047_Game_Qubbeya-Harran-2010.xml done
# validating ../010_manannot/Urfa-047_Game_Qubbeya-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 200, 'source': '../010_manannot/Urfa-047_Game_Qubbeya-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[1]/tei:u[1]/tei:w[15]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 55 in total
# Urfa-048_Game_Cab-Harran-2010.xml done
# validating ../010_manannot/Urfa-048_Game_Cab-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 313, 'source': '../010_manannot/Urfa-048_Game_Cab-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[4]/tei:u[1]/tei:w[11]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 56 in total
# Urfa-054_Real_Friend-Harran-2010.xml done
# validating ../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Invalid attribute when for element change', 'line': 138, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/*/*[1]/*[4]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Invalid attribute when for element change', 'line': 138, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/*/*[1]/*[4]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 238, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[2]/tei:u[1]/tei:w[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 736, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[17]/tei:u[1]/tei:w[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 863, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[20]/tei:u[1]/tei:w[4]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 60 in total
# Urfa-057_Story_of_Magician-Harran-2010.xml done
# validating ../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 467, 'source': '../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[3]/tei:u[1]/tei:w[72]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 61 in total
# Urfa-061_Life_of_al-Harrani-Harran-2010.xml done
# validating ../010_manannot/Urfa-061_Life_of_al-Harrani-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 61 in total
# Urfa-068_Tribes_Armenians_Jews-Harran-2010.xml done
# validating ../010_manannot/Urfa-068_Tribes_Armenians_Jews-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 746, 'source': '../010_manannot/Urfa-068_Tribes_Armenians_Jews-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[10]/tei:u[1]/tei:w[20]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 808, 'source': '../010_manannot/Urfa-068_Tribes_Armenians_Jews-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[10]/tei:u[11]/tei:w[4]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 814, 'source': '../010_manannot/Urfa-068_Tribes_Armenians_Jews-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[10]/tei:u[11]/tei:w[8]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 2466, 'source': '../010_manannot/Urfa-068_Tribes_Armenians_Jews-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[40]/tei:u[1]/tei:w[18]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 65 in total
# Urfa-069a_Armenians-Harran-2010.xml done
# validating ../010_manannot/Urfa-069a_Armenians-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 65 in total
# Urfa-069b_Arabicised_Kurds-Harran-2010.pfsx.xml done
# validating ../010_manannot/Urfa-069b_Arabicised_Kurds-Harran-2010.pfsx.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 220, 'source': '../010_manannot/Urfa-069b_Arabicised_Kurds-Harran-2010.pfsx.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[1]/tei:u[2]/tei:w[16]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 261, 'source': '../010_manannot/Urfa-069b_Arabicised_Kurds-Harran-2010.pfsx.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[2]/tei:u[1]/tei:w[8]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 294, 'source': '../010_manannot/Urfa-069b_Arabicised_Kurds-Harran-2010.pfsx.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[3]/tei:u[1]/tei:w[4]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 68 in total
# Urfa-070_Hen_House-Harran-2010.xml done
# validating ../010_manannot/Urfa-070_Hen_House-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 68 in total
# Urfa-072_Villages-Harran-2010.xml done
# validating ../010_manannot/Urfa-072_Villages-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 293, 'source': '../010_manannot/Urfa-072_Villages-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[2]/tei:u[1]/tei:w[29]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1000, 'source': '../010_manannot/Urfa-072_Villages-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[14]/tei:u[1]/tei:w[13]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1216, 'source': '../010_manannot/Urfa-072_Villages-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[17]/tei:u[4]/tei:w[9]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1217, 'source': '../010_manannot/Urfa-072_Villages-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[17]/tei:u[4]/tei:w[10]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1219, 'source': '../010_manannot/Urfa-072_Villages-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[17]/tei:u[4]/tei:w[11]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1220, 'source': '../010_manannot/Urfa-072_Villages-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[17]/tei:u[4]/tei:w[12]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1221, 'source': '../010_manannot/Urfa-072_Villages-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[17]/tei:u[4]/tei:w[13]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1236, 'source': '../010_manannot/Urfa-072_Villages-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[17]/tei:u[5]/tei:w[11]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 76 in total
# Urfa-073_Talls_Flood-Harran-2010.xml done
# validating ../010_manannot/Urfa-073_Talls_Flood-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 251, 'source': '../010_manannot/Urfa-073_Talls_Flood-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[3]/tei:u[1]/tei:w[10]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 77 in total
# Urfa-074_Talls_Burial_for_Children-Harran-2010.xml done
# validating ../010_manannot/Urfa-074_Talls_Burial_for_Children-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 77 in total
# Urfa-075_Corn_and_Language-Harran-2010.xml done
# validating ../010_manannot/Urfa-075_Corn_and_Language-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 77 in total
# Urfa-076_Bedouins-Harran-2010.xml done
# validating ../010_manannot/Urfa-076_Bedouins-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 498, 'source': '../010_manannot/Urfa-076_Bedouins-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[7]/tei:u[1]/tei:w[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 78 in total
# Urfa-077a_The_Jinn-Harran-2010.xml done
# validating ../010_manannot/Urfa-077a_The_Jinn-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 78 in total
# Urfa-077b_The_Jinn-Harran-2010.xml done
# validating ../010_manannot/Urfa-077b_The_Jinn-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 78 in total
# Urfa-077c_The_Jinn-Harran-2010.xml done
# validating ../010_manannot/Urfa-077c_The_Jinn-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 446, 'source': '../010_manannot/Urfa-077c_The_Jinn-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[4]/tei:u[1]/tei:w[13]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 79 in total
# Urfa-077d_The_Jinn-Harran-2010.xml done
# validating ../010_manannot/Urfa-077d_The_Jinn-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 586, 'source': '../010_manannot/Urfa-077d_The_Jinn-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[6]/tei:u[1]/tei:w[21]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 80 in total
# Urfa-077e_The_Jinn-Harran-2010.xml done
# validating ../010_manannot/Urfa-077e_The_Jinn-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 473, 'source': '../010_manannot/Urfa-077e_The_Jinn-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[4]/tei:u[1]/tei:w[5]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 816, 'source': '../010_manannot/Urfa-077e_The_Jinn-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[8]/tei:u[1]/tei:w[37]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 1096, 'source': '../010_manannot/Urfa-077e_The_Jinn-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[12]/tei:u[2]/tei:w[4]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 1233, 'source': '../010_manannot/Urfa-077e_The_Jinn-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[14]/tei:u[1]/tei:w[8]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 84 in total
# Urfa-080_Gazelles_and_Jews-Harran-2010.xml done
# validating ../010_manannot/Urfa-080_Gazelles_and_Jews-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 357, 'source': '../010_manannot/Urfa-080_Gazelles_and_Jews-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[4]/tei:u[1]/tei:w[19]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 750, 'source': '../010_manannot/Urfa-080_Gazelles_and_Jews-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[10]/tei:u[1]/tei:w[18]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 86 in total
# Urfa-081_Food_in_Former_Times-Harran-2010.xml done
# validating ../010_manannot/Urfa-081_Food_in_Former_Times-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.shtaha_00000'", 'line': 360, 'source': '../010_manannot/Urfa-081_Food_in_Former_Times-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[4]/tei:u[1]/tei:w[16]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 87 in total
# Urfa-085_The_Snake_in_the_Cistern-Harran-2010.xml done
# validating ../010_manannot/Urfa-085_The_Snake_in_the_Cistern-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1586, 'source': '../010_manannot/Urfa-085_The_Snake_in_the_Cistern-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[22]/tei:u[1]/tei:w[45]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 88 in total
# Urfa-087_Smide-Harran-2010.xml done
# validating ../010_manannot/Urfa-087_Smide-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 88 in total
# Urfa-092_Sultan_Murad-Harran-2010.xml done
# validating ../010_manannot/Urfa-092_Sultan_Murad-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 1061, 'source': '../010_manannot/Urfa-092_Sultan_Murad-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[13]/tei:u[1]/tei:w[34]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 2197, 'source': '../010_manannot/Urfa-092_Sultan_Murad-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[29]/tei:u[1]/tei:w[60]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 90 in total
# Urfa-094_Three_Advices-Harran-2010.xml done
# validating ../010_manannot/Urfa-094_Three_Advices-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 1030, 'source': '../010_manannot/Urfa-094_Three_Advices-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[22]/tei:u[1]/tei:w[12]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 1971, 'source': '../010_manannot/Urfa-094_Three_Advices-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[44]/tei:u[1]/tei:w[49]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 2043, 'source': '../010_manannot/Urfa-094_Three_Advices-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[45]/tei:u[1]/tei:w[28]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 2119, 'source': '../010_manannot/Urfa-094_Three_Advices-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[46]/tei:u[1]/tei:w[25]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 2271, 'source': '../010_manannot/Urfa-094_Three_Advices-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[49]/tei:u[1]/tei:w[6]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 2752, 'source': '../010_manannot/Urfa-094_Three_Advices-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[56]/tei:u[1]/tei:w[6]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 96 in total
# Urfa-097_Three_Daughters-Harran-2010.xml done
# validating ../010_manannot/Urfa-097_Three_Daughters-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 96 in total
# Urfa-098_Young_Woman-Harran-2010.xml done
# validating ../010_manannot/Urfa-098_Young_Woman-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 96 in total
# Urfa-105_Life_in_Former_Times-Harran-2010.xml done
# validating ../010_manannot/Urfa-105_Life_in_Former_Times-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 96 in total
# Urfa-106_Visa_in_Ankara-Harran-2010.xml done
# validating ../010_manannot/Urfa-106_Visa_in_Ankara-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 96 in total
# Urfa-107_Cotton_Business-Harran-2010.xml done
# validating ../010_manannot/Urfa-107_Cotton_Business-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Invalid attribute text for element w', 'line': 539, 'source': '../010_manannot/Urfa-107_Cotton_Business-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[12]/*[1]/*[2]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# {'type': 'error', 'message': 'Invalid attribute text for element w', 'line': 2940, 'source': '../010_manannot/Urfa-107_Cotton_Business-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[113]/*[1]/*[8]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Invalid attribute text for element w', 'line': 539, 'source': '../010_manannot/Urfa-107_Cotton_Business-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[12]/*[1]/*[2]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'Invalid attribute text for element w', 'line': 2940, 'source': '../010_manannot/Urfa-107_Cotton_Business-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[113]/*[1]/*[8]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 2563, 'source': '../010_manannot/Urfa-107_Cotton_Business-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[98]/tei:u[1]/tei:w[4]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 99 in total
# Urfa-110_Salim_az-Zir-Harran-2010.xml done
# validating ../010_manannot/Urfa-110_Salim_az-Zir-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 99 in total
# Urfa-112_Tall_Nasir-Harran-2010.xml done
# validating ../010_manannot/Urfa-112_Tall_Nasir-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 99 in total
# Urfa-115_Camel-Harran-2010.xml done
# validating ../010_manannot/Urfa-115_Camel-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 99 in total
# Urfa-119_Engagement-Harran-2010.xml done
# validating ../010_manannot/Urfa-119_Engagement-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Invalid attribute text for element w', 'line': 311, 'source': '../010_manannot/Urfa-119_Engagement-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[5]/*[1]/*[19]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Invalid attribute text for element w', 'line': 311, 'source': '../010_manannot/Urfa-119_Engagement-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[5]/*[1]/*[19]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}]
# 0 found / 100 in total
# Urfa-120_Cross_Marriage-Harran-2010.xml done
# validating ../010_manannot/Urfa-120_Cross_Marriage-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Element w failed to validate attributes', 'line': 0, 'source': '../010_manannot/Urfa-120_Cross_Marriage-Harran-2010.xml', 'location': 'n/a', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# {'type': 'error', 'message': 'Element w failed to validate attributes', 'line': 0, 'source': '../010_manannot/Urfa-120_Cross_Marriage-Harran-2010.xml', 'location': 'n/a', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Element w failed to validate attributes', 'line': 0, 'source': '../010_manannot/Urfa-120_Cross_Marriage-Harran-2010.xml', 'location': 'n/a', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'Element w failed to validate attributes', 'line': 0, 'source': '../010_manannot/Urfa-120_Cross_Marriage-Harran-2010.xml', 'location': 'n/a', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}]
# 0 found / 102 in total
# Urfa-122_Nimrod-Harran-2010.xml done
# validating ../010_manannot/Urfa-122_Nimrod-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 971, 'source': '../010_manannot/Urfa-122_Nimrod-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[14]/tei:u[1]/tei:w[7]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 103 in total
# Urfa-123_Stealing_Boy_P1-Harran-2010.xml done
# validating ../010_manannot/Urfa-123_Stealing_Boy_P1-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 103 in total
# Urfa-124_Stealing_Boy_P2-Harran-2010.xml done
# validating ../010_manannot/Urfa-124_Stealing_Boy_P2-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 983, 'source': '../010_manannot/Urfa-124_Stealing_Boy_P2-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[21]/tei:u[1]/tei:w[28]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 1007, 'source': '../010_manannot/Urfa-124_Stealing_Boy_P2-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[22]/tei:u[1]/tei:w[6]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 1012, 'source': '../010_manannot/Urfa-124_Stealing_Boy_P2-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[22]/tei:u[1]/tei:w[10]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 106 in total
# Urfa-125_Coffee-Harran-2010.xml done
# validating ../010_manannot/Urfa-125_Coffee-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 106 in total
# Urfa-133_Sheikh_Musa-Harran-2013.xml done
# validating ../010_manannot/Urfa-133_Sheikh_Musa-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Invalid attribute high for element w', 'line': 1115, 'source': '../010_manannot/Urfa-133_Sheikh_Musa-Harran-2013.xml', 'location': '/*/*[2]/*[2]/*/*[28]/*[1]/*[31]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Invalid attribute high for element w', 'line': 1115, 'source': '../010_manannot/Urfa-133_Sheikh_Musa-Harran-2013.xml', 'location': '/*/*[2]/*[2]/*/*[28]/*[1]/*[31]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 3313, 'source': '../010_manannot/Urfa-133_Sheikh_Musa-Harran-2013.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[97]/tei:u[1]/tei:w[10]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "The 'who' attribute of u must point to a person defined in the header", 'line': 1877, 'source': '../010_manannot/Urfa-133_Sheikh_Musa-Harran-2013.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[52]/tei:u[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "The 'who' attribute of u must point to a person defined in the header", 'line': 1915, 'source': '../010_manannot/Urfa-133_Sheikh_Musa-Harran-2013.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[53]/tei:u[1]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 110 in total
# Urfa-135_Burglars_From_Syria-Harran-2013.xml done
# validating ../010_manannot/Urfa-135_Burglars_From_Syria-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 778, 'source': '../010_manannot/Urfa-135_Burglars_From_Syria-Harran-2013.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[12]/tei:u[1]/tei:w[8]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cin_00000'", 'line': 813, 'source': '../010_manannot/Urfa-135_Burglars_From_Syria-Harran-2013.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[13]/tei:u[1]/tei:w[3]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 112 in total
# Urfa-136_Cigkofte-Harran-2013.xml done
# validating ../010_manannot/Urfa-136_Cigkofte-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Expecting an element , got nothing', 'line': 148, 'source': '../010_manannot/Urfa-136_Cigkofte-Harran-2013.xml', 'location': '/*/*[1]/*[3]/*[3]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Expecting an element , got nothing', 'line': 148, 'source': '../010_manannot/Urfa-136_Cigkofte-Harran-2013.xml', 'location': '/*/*[1]/*[3]/*[3]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}]
# 0 found / 113 in total
# Urfa-137_Kazan_Kebab-Harran-2013.xml done
# validating ../010_manannot/Urfa-137_Kazan_Kebab-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 113 in total
# Urfa-138_Kazan_Kebab-Harran-2013.xml done
# validating ../010_manannot/Urfa-138_Kazan_Kebab-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 113 in total
# Urfa-139_Lahmacun-Harran-2013.xml done
# validating ../010_manannot/Urfa-139_Lahmacun-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 113 in total
# Urfa-140_Biyat-Harran-2013.xml done
# validating ../010_manannot/Urfa-140_Biyat-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 113 in total
# ID URFA-141_xTok_000268 already defined, line 485, column 141 (../010_manannot/Urfa-141_Istishara-Harran-2013.xml, line 485)
# Urfa-141_Istishara-Harran-2013.xml None
# validating ../010_manannot/Urfa-141_Istishara-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'ID URFA-141_xTok_000268 already defined, line 485, column 141 (../010_manannot/Urfa-141_Istishara-Harran-2013.xml, line 485)', 'line': 485, 'source': '../010_manannot/Urfa-141_Istishara-Harran-2013.xml', 'location': 'n/a', 'stage': 'parsing', 'exceptionType': 'XMLSyntaxError'}
# Urfa-142_Chilli_Pepper-Harran-2013.xml done
# validating ../010_manannot/Urfa-142_Chilli_Pepper-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1192, 'source': '../010_manannot/Urfa-142_Chilli_Pepper-Harran-2013.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[19]/tei:u[1]/tei:w[22]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1193, 'source': '../010_manannot/Urfa-142_Chilli_Pepper-Harran-2013.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[19]/tei:u[1]/tei:w[23]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 115 in total
# ID URFA-144_xTok_000568 already defined, line 737, column 157 (../010_manannot/Urfa-144_Malfuf-Harran-2013.xml, line 737)
# Urfa-144_Malfuf-Harran-2013.xml None
# validating ../010_manannot/Urfa-144_Malfuf-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'ID URFA-144_xTok_000568 already defined, line 737, column 157 (../010_manannot/Urfa-144_Malfuf-Harran-2013.xml, line 737)', 'line': 737, 'source': '../010_manannot/Urfa-144_Malfuf-Harran-2013.xml', 'location': 'n/a', 'stage': 'parsing', 'exceptionType': 'XMLSyntaxError'}
# Urfa-145_Prophet_Ayyub-Harran-2013.xml done
# validating ../010_manannot/Urfa-145_Prophet_Ayyub-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 115 in total
# Urfa-146_Wolf-Harran-2013.xml done
# validating ../010_manannot/Urfa-146_Wolf-Harran-2013.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "@lemmaRef is required when xml:lang is 'ar-acm-x-shawi-vicav' and type is not truncated", 'line': 1786, 'source': '../010_manannot/Urfa-146_Wolf-Harran-2013.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[38]/tei:u[1]/tei:w[12]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 116 in total
# Urfa-149_Bird-Harran-2014.xml generated
# Urfa-150_Iclikofte-Harran-2014.xml draft
# Urfa-151_Ashura-Harran-2014.xml draft
# Urfa-152_Dream-Harran-2014.xml draft
# Urfa-153_Sheikh_Hasan-Harran-2014.xml draft
# Urfa-155_Childhood-Harran-2014.xml draft
# Urfa-158_Moses_and_Dog-Harran-2014.xml draft
# Urfa-160_Seyhmus-Harran-2014.xml draft
# Urfa-162_Umm_al-Qet-Harran-2014.xml draft
# Urfa-163_Quilts-Harran-2014.xml draft
# Urfa-164_Baking_Bread-Harran-2014.xml draft
# Urfa-165_Childhood-Harran-2014.xml generated
# Urfa-167_Sheikh_'Nad-Harran-2014.xml draft
# Urfa-173_Woman_with_No_Lover_Short-Harran-2014.xml draft
# Urfa-175_Bastig-Harran-2014.xml draft
# Urfa-176_Condolences-Harran-2014.xml draft
# Urfa-177_Wedding_in_Former_Times-Harran-2014.xml generated
# Urfa-179_Grandfather-Harran-2014.xml generated
# Urfa-183_Policeman_and_Carp-Harran-2014.xml draft
# Urfa-184_Evil_Eye-Harran-2014.xml draft
# Urfa-187_Two_Women_and_Fridge-Harran-2015.xml draft
# Urfa-188_Shepherd-Harran-2015.xml generated
# Urfa-189_Wanted_to_Marry-Harran.xml generated
# Urfa-190_ill_Blind_Mother-Harran-2015.xml generated
# Urfa-191_Kurd_and_Two_Wives-Harran-2015.xml generated
# Urfa-192_Who_chooses_a_horse-Harran.xml generated
# Urfa-193_Priapism-Harran-2015.xml generated
# Urfa-194_Afraid_of_Dogs-Harran-2017.xml generated
# Urfa-195_Best_and_Worst_Part_of_the_Sheep-Harran-2017.xml generated
# Urfa-201_Story_of_Cigkofte-Harran-2017.xml generated
# Urfa-202_Al-Shukwa-Harran-2017.xml generated
# Urfa-203_Tattooing-Harran-2017.xml generated
# Urfa-352_Washing_Clothes-Harran-2021.xml generated
# Urfa-355_Threshing_wheat_in_former_times.xml generated
# Urfa-428_How_not_to_get_married_to_an_old_man.xml generated
# Urfa-467_The_big_earthquake_of_February_2023.xml generated

# %%
def make_clickable(source, line=None):
    link = source.replace('../','https://github.com/acdh-oeaw/shawi-data/tree/main/')
    if line:
        return f'<a href="{link}#L{line}">{source}</a>'
    else:
        return f'<a href="{link}">{source}</a>'

# %%
if len(ignoredFiles) > 0:
    df_ignored = pd.DataFrame(data=ignoredFiles).T
    df_ignored = df_ignored.transpose()
    df_ignored
    ignoredReport = "tmp/ignoredFiles.html"
    df_ignored['link'] = df_ignored.apply(lambda x: make_clickable(x['source']), axis=1)

    with open(ignoredReport, 'w', encoding='utf-8') as f:
        f.write(df_ignored.to_html(render_links=True, escape=False))

# %%
if len(validationErrors) > 0:
    df_err = pd.DataFrame(data=validationErrors).T
    df_err = df_err.transpose()
    df_err
    print(f"found {len(validationErrors)} validation errors")
    #df_err = df_err[df_err["message"].str.contains("@lemmaRef is required when xml:lang is 'ar-acm")==False]
    #df_err = df_err[df_err["message"].str.contains("There is no entry in the dictionary for the")==True]
    errorReport = "tmp/validationReport.html"
    df_err['link'] = df_err.apply(lambda x: make_clickable(x['source'], x['line']), axis=1)
    with open(errorReport, 'w', encoding='utf-8') as f:
        f.write(df_err.to_html(render_links=True, escape=False))
# Out:
# found 116 validation errors

# %%
df_err
# Out:
#       type                                            message  line  \
# 0    error  There is no entry in the dictionary for the cu...   328
# 1    error  @lemmaRef is required when xml:lang is 'ar-acm...  1017
# 2    error  @lemmaRef is required when xml:lang is 'ar-acm...   399
# 3    error  @lemmaRef is required when xml:lang is 'ar-acm...   469
# 4    error                   Did not expect element div there   234
# ..     ...                                                ...   ...
# 111  error  There is no entry in the dictionary for the cu...   813
# 112  error                 Expecting an element , got nothing   148
# 113  error  @lemmaRef is required when xml:lang is 'ar-acm...  1192
# 114  error  @lemmaRef is required when xml:lang is 'ar-acm...  1193
# 115  error  @lemmaRef is required when xml:lang is 'ar-acm...  1786
#
#                                                 source  \
# 0      ../010_manannot/Urfa-000_Namrud-Harran-2001.xml
# 1      ../010_manannot/Urfa-000_Namrud-Harran-2001.xml
# 2     ../010_manannot/Urfa-002a_Joke_about_a_tribe.xml
# 3     ../010_manannot/Urfa-002a_Joke_about_a_tribe.xml
# 4     ../010_manannot/Urfa-011_Cemetry-Harran-2010.xml
# ..                                                 ...
# 111  ../010_manannot/Urfa-135_Burglars_From_Syria-H...
# 112  ../010_manannot/Urfa-136_Cigkofte-Harran-2013.xml
# 113  ../010_manannot/Urfa-142_Chilli_Pepper-Harran-...
# 114  ../010_manannot/Urfa-142_Chilli_Pepper-Harran-...
# 115      ../010_manannot/Urfa-146_Wolf-Harran-2013.xml
#
#                                               location       stage  \
# 0    /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 1    /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 2    /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 3    /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 4                                  /*/*[2]/*[2]/*/*[2]     relaxng
# ..                                                 ...         ...
# 111  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 112                                  /*/*[1]/*[3]/*[3]     relaxng
# 113  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 114  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 115  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
#
#        exceptionType                                               link
# 0      failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 1      failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 2      failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 3      failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 4    DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# ..               ...                                                ...
# 111    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 112  DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# 113    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 114    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 115    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
#
# [116 rows x 8 columns]
