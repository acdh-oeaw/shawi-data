# %% [markdown]
# # Validating finished Shawi Corpus Files
#
# * Install & set up dependencies
# * extract schematron from RNG and transform to XSLT
# * run schematron-xslt on files

# %%
import io
import os
import requests
import pathlib
import re
import sys
import json
import pandas as pd
import linecache as lc
import shutil

from copy import deepcopy
from pathlib import Path
from urllib.parse import urlsplit
import saxonche
from zipfile import ZipFile
from lxml import isoschematron, etree

# %%
tmpDir = "tmp"
libDir = "lib"
os.makedirs(tmpDir, exist_ok=True)
os.makedirs(libDir, exist_ok=True)
namespaces = {"tei":"http://www.tei-c.org/ns/1.0"}
dataHome = ".."

# rng schema
rngSchema = dataHome + "/802_tei_odd/out/shawi_corpus.rng"
# dict rng schema
dictRngSchema = dataHome + "/802_tei_odd/out/shawi_dict.rng"
# the path to the annotated TEI transcription files
manannot = dataHome + "/010_manannot"
manannot_new = manannot + "/New"
manannots = [manannot, manannot_new]
# the path to the dictionary
dictionary = dataHome + "/vicav_dicts/dc_shawi_eng.xml"
# automatically edited version with stubs removed
# Needs to be at the same location as the original as there are references to files
# that are relative to the original file.
dictionary_draft_and_released = dataHome + "/vicav_dicts/tmp_dc_shawi_eng_draft_and_released.xml"

# include those documents in validation which have the following status in //tei:revisionDesc/@status / ignore all others
VALIDATE_DOCS_WITH_STATUS = "done"

with saxonche.PySaxonProcessor(license=False) as proc:
    print(proc.version)
    proc.set_cwd(os.path.dirname(os.path.dirname(os.path.abspath(''))))
    print(proc.cwd)
# Out:
# SaxonC-HE 12.9 from Saxonica
# /Users/osiam/BaseX/BaseXShawi

# %%
def downloadAndStore(url, force=False):   
    #  filename of the file to be downloaded
    fn = os.path.basename(url)
    # fn w/o extension
    basename = os.path.splitext(fn)[0]
    # extension 
    ext = os.path.splitext(fn)[1]
    dlFilePath = tmpDir + "/" + fn
    if not os.path.exists(dlFilePath) and not force == True:
        payload = requests.get(url).content
        open(dlFilePath, 'wb').write(payload)
    return dlFilePath

# %%
def downloadAndUnzip(url):    
    #  filename of the file to be downloaded
    fn = os.path.basename(url)
    # fn w/o extension
    basename = os.path.splitext(fn)[0]
    # extension 
    ext = os.path.splitext(fn)[1]
    
    if ext != ".zip":
        return "not a zip archive"
    else:
        zipFilePath = downloadAndStore(url)
        # the path where the content should be extracted to
        targetPath = libDir + "/" + basename
        
        
        payload = requests.get(url).content
        open(zipFilePath, 'wb').write(payload)
        ZipFile(zipFilePath).extractall(path=targetPath)
    
    return targetPath

# %%
def transform(s, xsl, o, parameters=[]):
    # processor keeps files open on Windows and in doing so prevents moving or copying them
    try:
        with saxonche.PySaxonProcessor(license=False) as proc:
            proc.set_configuration_property("xi", "on")
            saxon = proc.new_xslt30_processor()
            for i in parameters:
                saxon.set_parameter(name=i, value=proc.make_string_value(parameters[i]))
            exec = saxon.compile_stylesheet(stylesheet_file=os.path.abspath(xsl))
            exec.apply_templates_returning_file(source_file=os.path.abspath(s), output_file=os.path.abspath(o))
            if exec.exception_occurred:
                exec.get_error_message
                #for i in range(saxon.exception_count()-1):
                print(saxon.get_error_message())
                print(os.path.abspath(s)+" - "+os.path.abspath(xsl)+" -> "+os.path.abspath(o)+" failed")
            if os.path.exists(os.path.abspath(o)):
                return o
            else: 
                print("there was an error transforming "+s+" with stylesheet "+xsl)
    except Exception as e:
        print("Python Exception during transform:", e)

# %% [markdown]
# ### Install XSL based schematron validator

# %%
_schCompiler = None
def setupSchXSLT():
    global _schCompiler
    if _schCompiler is not None:
        return _schCompiler
    schDLURL = "https://codeberg.org/SchXslt/schxslt/releases/download/v1.10.1/schxslt-1.10.1-xslt-only.zip"
    schHome = downloadAndUnzip(schDLURL)
    _schCompiler = schHome + "/schxslt-1.10.1/2.0/pipeline-for-svrl.xsl"
    if os.path.exists(_schCompiler):
        return _schCompiler
    else: 
        print("error: something went wrong, cannot locate file '" + schCompiler + "'")

# %%
setupSchXSLT()
# Out:
# 'lib/schxslt-1.10.1-xslt-only/schxslt-1.10.1/2.0/pipeline-for-svrl.xsl'

# %% [markdown]
# ## Prepare rng2sch stylesheet
#
# Returns path to the xsl that extracts schematron form the RelaxNG schema.
# This should only run once as the file gets locked (by saxon) and so further attempts to pring it to the correct location will fail.

# %%
_rng2sch = None 
def setupRNG2Sch():
    global _rng2sch
    if _rng2sch is not None:
        return _rng2sch
    RNG2SchtrDL = "https://raw.githubusercontent.com/Schematron/schematron/master/trunk/converters/code/ToSchematron/ExtractSchFromRNG.xsl"
    dltmp = downloadAndStore(RNG2SchtrDL)
    # tweak XSLT 
    with open(dltmp, encoding='utf-8') as inputfile:
        lines = inputfile.read()
    lines = lines.replace( 'http://www.ascc.net/xml/schematron','http://purl.oclc.org/dsdl/schematron/')
    lines = lines.replace( '<sch:schema','<sch:schema queryBinding="xslt2"')
    
    with open(dltmp, 'w', encoding='utf-8') as file:
        file.writelines(lines)
    _rng2sch = libDir+"/"+os.path.basename(dltmp)
    os.replace(dltmp, _rng2sch)
    if os.path.exists(_rng2sch):
        return _rng2sch
    else:
        print("error: something went wrong, cannot locate file '" + newPath + "'")

# %%
setupRNG2Sch()
# Out:
# 'lib/ExtractSchFromRNG.xsl'

# %% [markdown]
# ## Extract schematron from RNG and transform to XSLT

# %%
def extractSchematron(rng):
    """extracts a schematron document embedded in an rng schema"""
    print("extracting Schematron document from "+rng)
    rng2sch = setupRNG2Sch()
    sch = tmpDir + "/" + os.path.basename(rng) + ".sch"
    if not os.path.exists(sch):
        transform(rng, rng2sch, sch)
    return sch

# %%
def compileSchematron(sch):
    """compiles a schematron document to an XSLT stylesheet"""
    outputPath = tmpDir + "/" + os.path.basename(sch) + ".xsl"
    schCompiler = setupSchXSLT()
    transform(sch, schCompiler, outputPath)
    
    if os.path.exists(outputPath):
        print(outputPath)
        return outputPath
    else: 
        print("error: something went wrong, cannot locate file '" + outputPath + "'")

# %%
sch = extractSchematron(rngSchema)
schXSL = compileSchematron(sch)
dictSch = extractSchematron(dictRngSchema)
dictSchXSL = compileSchematron(dictSch)
# Out:
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# tmp/shawi_corpus.rng.sch.xsl
# extracting Schematron document from ../802_tei_odd/out/shawi_dict.rng
# tmp/shawi_dict.rng.sch.xsl

# %% [markdown]
# ## Run schematron and relaxNG on files

# %%
validationErrors = []
ignoredFiles = []
dictValidationErrors = []

# %%
def schValidate(schXSL, path):
    print("path: ", path)
    """validates a document (at path) against an XSL compiled schematron schema (at schXSL)"""
    errs = []
    out = tmpDir + "/validationReports/" + os.path.basename(path)

    try:
        transform(path, schXSL, out)

    except saxonche.PySaxonApiError as e:
        # We swallow parsing errors here as they should have been reported by lxml already
        print("an error occured while running schValidate on "+path)
        return []
    
    report = etree.parse(out)
    successfulReport = report.findall("{http://purl.oclc.org/dsdl/svrl}successful-report")
    failedAssert = report.findall("{http://purl.oclc.org/dsdl/svrl}failed-assert")
    doc = etree.parse(path)
    for s in successfulReport + failedAssert:
        XPath = s.attrib['location'].replace('Q{http://www.tei-c.org/ns/1.0}','tei:').replace('Q{}','')
        entry_xpath = f"{XPath}/ancestor::tei:entry[1]"
        if entry_xpath is not None and doc.xpath(entry_xpath, namespaces=namespaces):
            entry = doc.xpath(entry_xpath, namespaces=namespaces)[0] 
            entry_id = entry.get("{http://www.w3.org/XML/1998/namespace}id")
            rel_path = XPath.split("tei:entry")[1].split("]", 1)[1].lstrip("/")
        else:
            entry_id = ""
            rel_path = ""
        # DEBUG
        node = doc.xpath(XPath, namespaces=namespaces)[0]
        if not(path.startswith("../010_manannot") or path.startswith("../../010_manannot")):
            node_with_line = tree_with_lines.xpath(XPath, namespaces=namespaces)[0]
            if node_with_line is not etree._Element:
                node_with_line = node_with_line.getparent()
            line_number = node_with_line.attrib.get("_line")
            path = "../vicav_dicts/dc_shawi_eng.xml"
        else:
            line_number = None
        if type(node) is etree._ElementUnicodeResult:
            elt = node.getparent()
        else:
            elt = node

        msg = s.find("{http://purl.oclc.org/dsdl/svrl}text").text

        errObj = {
            "type" : "error",
            "message":  msg,
            "line" : line_number or elt.sourceline,
            "source": path,
            "entry": entry_id,
            "relativePath": rel_path,
            "location": XPath,
            #"text": elt.text, #checking text values (for @lemmaRef)
            "stage": "schematron",
            "exceptionType": str(s.tag).replace("{http://purl.oclc.org/dsdl/svrl}",""),
        }
        
        errs.append(errObj)
    return errs

# %%
def validate(path, rngSchema, schematronSchemaXSL):
    """Validate a document against the rngSchema. Returns a list of dicts of which each one represents a validation (or parsing) error."""
    validationErrors = []
    shutil.copyfile(sch, '../802_tei_odd/out/'+os.path.basename(sch)) #copy file from tmp folder into odd folder to be able to git it
    try:
        doc = etree.parse(path)
    
        # relaxng validation
        relaxng_doc = etree.parse(rngSchema)
        relaxng = etree.RelaxNG(relaxng_doc)
        try:
            relaxng.assertValid(doc)
        except etree.DocumentInvalid:
            for error in relaxng.error_log:
                print(
                    f"Line {error.line}, Column {error.column}: {error.message}"
                )
        
        # schematron validation
        schErrs = schValidate(schematronSchemaXSL, path)
        if len(schErrs) >= 1:
            validationErrors = validationErrors + schErrs
    except etree.XMLSyntaxError as e:
        valErrObj = {
            "type" : "error",
            "message": str(e), 
            "line": e.lineno,
            "source": path, 
            "location": "n/a",
            "stage" : "parsing", 
            "exceptionType": type(e).__name__
        }
        return valErrObj
        
    except etree.DocumentInvalid as e:
        for error in e.error_log:
            # we ignore rng errors about @schemaLocation since 
            # that is needed for validation in the TEI-enricher
            if error.message != "Invalid attribute schemaLocation for element TEI":
                location = "n/a" if error.path is None else error.path
                if not(path.startswith("../010_manannot") or path.startswith("../../010_manannot")):
                    curr_path = "../vicav_dicts/dc_shawi_eng.xml"
                    entry_xpath = f"{error.path}/ancestor::tei:entry[1]"
                    if entry_xpath is not None and doc.xpath(entry_xpath, namespaces=namespaces):
                        entry = doc.xpath(entry_xpath, namespaces=namespaces)[0] 
                        entry_id = entry.get("{http://www.w3.org/XML/1998/namespace}id")
                    else:
                        entry_id = ""
                else:
                    curr_path = None
                    entry_id = None

                valErrObj = {
                    "type" : "error",
                    "message": error.message, 
                    "line": error.line, 
                    "source": curr_path or path,
                    "entry": entry_id,
                    "relativePath": None,
                    "location": location,
                    "stage" : "relaxng", 
                    "exceptionType": type(e).__name__
                }
                # DEBUG
                #print(valErrObj)
                validationErrors.append(valErrObj)
        
        # if the document is invalid against the RNG, we still want to run schematron against it
        schErrs = schValidate(schematronSchemaXSL, path)
        if len(schErrs) >= 1:
            validationErrors = validationErrors + schErrs
            
    return validationErrors

# %%
def docStatus(path):
    """returns the status of the document at path; if the document can't be parsed, it returns a dict with the error"""
    try:
        doc = etree.parse(path)
        revisionDesc = doc.xpath("/tei:TEI/tei:teiHeader/tei:revisionDesc", namespaces=namespaces)[0]
        status = revisionDesc.attrib['status']
        return status
    # report documents which are not well-formed
    except etree.XMLSyntaxError as e:
        valErrObj = {
                    "type" : "error",
                    "message": e, 
                    "line": "",
                    "source": path,
                    "entry": "",
                    "relativePath": None,
                    "location": None,
                    "stage" : "relaxng", 
                    "exceptionType": type(e).__name__
        }
        validationErrors.append(valErrObj)

# %% [markdown]
# # remove all entries where the last fs element contains the status stub

# %%
def indent(tree):
    teiHeader = tree.find('.//tei:teiHeader', namespaces=namespaces)
    teiText = tree.find('.//tei:text', namespaces=namespaces)
    etree.indent(teiHeader, space='   ', level=0)
    etree.indent(teiText, space='   ', level=0)

# %%
def get_dict_with_draft_and_released():
    with open(dictionary, encoding="utf8") as file:
        tree = etree.parse(file)

    for line in tree.iter():
        if isinstance(line, etree._Comment):
            continue
        line.set("_line", str(line.sourceline))
    
    entries = tree.findall(f'.//tei:entry', namespaces=namespaces)
    for entry in entries:
        fss = entry.findall(f'.//tei:fs', namespaces=namespaces)
        if not fss:
            #print(f"No fs elements in entry {entry.attrib}")
            continue
        
        symbol = fss[-1].find(f'tei:f[@name="status"]/tei:symbol', namespaces=namespaces)
        if symbol is None:
            #print(f'no f name status found for {entry.attrib}')
            continue

        status = symbol.get("value")
        
        if status != "draft" and status != "released":
            entry.getparent().remove(entry)
            
    # copy the tree for line number retrieval, causing no errors because of surplus attribute "_line"
    tree_with_lines = deepcopy(tree)
    
    for el in tree.iter():
        el.attrib.pop("_line", None)
        
    indent(tree)
    
    with open(dictionary_draft_and_released, 'wb') as file:
        file.write(etree.tostring(tree, pretty_print=True, encoding='UTF-8'))
        
    return tree_with_lines

# %%
def validateAndAppend(filepath, rngSchema, schXSL, is_dict_validation):
    global validationErrors, ignoredFiles, dictValidationErrors
    print("validating " + filepath)
    results = validate(filepath, rngSchema, schXSL)
    #print(results)
    len(results)
    if type(results) is list:
        res_errs = filter(lambda x: x['type'] == "error", results)
        res_ignored = filter(lambda x: x['type'] == "ignored", results)
        if is_dict_validation is not None:
            dictValidationErrors = dictValidationErrors + list(res_errs)
            print(f"{len(list(res_errs))} found / {len(dictValidationErrors)} in total")
        else:
            validationErrors = validationErrors + list(res_errs)
            print(f"{len(list(res_errs))} found / {len(validationErrors)} in total")
    elif type(results) is dict:
        if results['type'] == "ignored":
            ignoredFiles.append(results)
    else:
        print("unknown result type")
        print(results)

# %%
tree_with_lines = get_dict_with_draft_and_released()

# %%
validateAndAppend(dictionary_draft_and_released, dictRngSchema, dictSchXSL, True)
# Out:
# validating ../vicav_dicts/tmp_dc_shawi_eng_draft_and_released.xml
# Line 8, Column 0: Element name failed to validate attributes
# Line 12, Column 0: Element name failed to validate attributes
# Line 16, Column 0: Element name failed to validate attributes
# Line 20, Column 0: Element name failed to validate attributes
# Line 25, Column 0: Element name failed to validate attributes
# Line 27, Column 0: Did not expect element funder there
# Line 36, Column 0: Element publisher has extra content: name
# Line 44, Column 0: Did not expect element date there
# Line 47, Column 0: Did not expect element p there
# Line 51, Column 0: Did not expect element listPrefixDef there
# path:  ../vicav_dicts/tmp_dc_shawi_eng_draft_and_released.xml
# 0 found / 16 in total

# %%
def validate_corpus_file(i, folder):
    filename = os.path.basename(i)
    filepath = folder + "/" + filename
    status = docStatus(filepath)
    print(filename, status)
    
    # if the document is not finished yet (//tei:revisionDesc/@status != DOCSTATUS_DONE), just ignore it
    if type(status) is str and status != VALIDATE_DOCS_WITH_STATUS:
        ignoredFiles.append({
            "source" : filepath,
            "type" : "ignored",
            "status": status
        })
    # if the document couldn't be parsed, docStatus() returns a dict 
    # with some error information which is appended to the list of 
    # validation errors
    elif type(status) is dict and status["type"] == "error":
        validationErrors.append(status) 
    
    # … otherwise try to validate the document
    else:
        validateAndAppend(filepath, rngSchema, schXSL, None)

# %%
for path in manannots:
    for i in os.scandir(path):
        if i.name.startswith('Urfa') and i.name.endswith('.xml') and i.is_file():
            validate_corpus_file(i, path)
# Out:
# Urfa-077b_The_Jinn-Harran-2010.xml done
# validating ../010_manannot/Urfa-077b_The_Jinn-Harran-2010.xml
# path:  ../010_manannot/Urfa-077b_The_Jinn-Harran-2010.xml
# 0 found / 0 in total
# Urfa-184_Evil_Eye-Harran-2014.xml done
# validating ../010_manannot/Urfa-184_Evil_Eye-Harran-2014.xml
# path:  ../010_manannot/Urfa-184_Evil_Eye-Harran-2014.xml
# 0 found / 0 in total
# Urfa-158_Moses_and_Dog-Harran-2014.xml done
# validating ../010_manannot/Urfa-158_Moses_and_Dog-Harran-2014.xml
# path:  ../010_manannot/Urfa-158_Moses_and_Dog-Harran-2014.xml
# 0 found / 0 in total
# Urfa-106_Visa_in_Ankara-Harran-2010.xml done
# validating ../010_manannot/Urfa-106_Visa_in_Ankara-Harran-2010.xml
# path:  ../010_manannot/Urfa-106_Visa_in_Ankara-Harran-2010.xml
# 0 found / 0 in total
# Urfa-152_Dream-Harran-2014.xml done
# validating ../010_manannot/Urfa-152_Dream-Harran-2014.xml
# path:  ../010_manannot/Urfa-152_Dream-Harran-2014.xml
# 0 found / 0 in total
# Urfa-138_Kazan_Kebab-Harran-2013.xml done
# validating ../010_manannot/Urfa-138_Kazan_Kebab-Harran-2013.xml
# path:  ../010_manannot/Urfa-138_Kazan_Kebab-Harran-2013.xml
# 0 found / 0 in total
# Urfa-163_Quilts-Harran-2014.xml done
# validating ../010_manannot/Urfa-163_Quilts-Harran-2014.xml
# path:  ../010_manannot/Urfa-163_Quilts-Harran-2014.xml
# 0 found / 0 in total
# Urfa-110_Salim_azZir-Harran-2010.xml done
# validating ../010_manannot/Urfa-110_Salim_azZir-Harran-2010.xml
# path:  ../010_manannot/Urfa-110_Salim_azZir-Harran-2010.xml
# 0 found / 0 in total
# Urfa-190_ill_Blind_Mother-Harran-2015.xml done
# validating ../010_manannot/Urfa-190_ill_Blind_Mother-Harran-2015.xml
# path:  ../010_manannot/Urfa-190_ill_Blind_Mother-Harran-2015.xml
# 0 found / 0 in total
# Urfa-165_Childhood-Harran-2014.xml done
# validating ../010_manannot/Urfa-165_Childhood-Harran-2014.xml
# path:  ../010_manannot/Urfa-165_Childhood-Harran-2014.xml
# 0 found / 0 in total
# Urfa-162_Umm_alQet-Harran-2014.xml done
# validating ../010_manannot/Urfa-162_Umm_alQet-Harran-2014.xml
# path:  ../010_manannot/Urfa-162_Umm_alQet-Harran-2014.xml
# 0 found / 0 in total
# Urfa-202_Shukwa-Harran-2017.xml done
# validating ../010_manannot/Urfa-202_Shukwa-Harran-2017.xml
# path:  ../010_manannot/Urfa-202_Shukwa-Harran-2017.xml
# 0 found / 0 in total
# Urfa-142_Chilli_Pepper-Harran-2013.xml done
# validating ../010_manannot/Urfa-142_Chilli_Pepper-Harran-2013.xml
# path:  ../010_manannot/Urfa-142_Chilli_Pepper-Harran-2013.xml
# 0 found / 0 in total
# Urfa-002a_Joke_about_a_Tribe-Harran-2001.xml done
# validating ../010_manannot/Urfa-002a_Joke_about_a_Tribe-Harran-2001.xml
# path:  ../010_manannot/Urfa-002a_Joke_about_a_Tribe-Harran-2001.xml
# 0 found / 0 in total
# Urfa-179_Grandfather-Harran-2014.xml done
# validating ../010_manannot/Urfa-179_Grandfather-Harran-2014.xml
# path:  ../010_manannot/Urfa-179_Grandfather-Harran-2014.xml
# 0 found / 0 in total
# Urfa-085_The_Snake_in_the_Cistern-Harran-2010.xml done
# validating ../010_manannot/Urfa-085_The_Snake_in_the_Cistern-Harran-2010.xml
# path:  ../010_manannot/Urfa-085_The_Snake_in_the_Cistern-Harran-2010.xml
# 0 found / 0 in total
# Urfa-189_Wanted_to_Marry-Harran-2015.xml done
# validating ../010_manannot/Urfa-189_Wanted_to_Marry-Harran-2015.xml
# path:  ../010_manannot/Urfa-189_Wanted_to_Marry-Harran-2015.xml
# 0 found / 0 in total
# Urfa-029_Smoking-Harran-2010.xml done
# validating ../010_manannot/Urfa-029_Smoking-Harran-2010.xml
# path:  ../010_manannot/Urfa-029_Smoking-Harran-2010.xml
# 0 found / 0 in total
# Urfa-092_Sultan_Murad-Harran-2010.xml done
# validating ../010_manannot/Urfa-092_Sultan_Murad-Harran-2010.xml
# path:  ../010_manannot/Urfa-092_Sultan_Murad-Harran-2010.xml
# 0 found / 0 in total
# Urfa-045_Gamra_Dariba-Harran-2010.xml done
# validating ../010_manannot/Urfa-045_Gamra_Dariba-Harran-2010.xml
# path:  ../010_manannot/Urfa-045_Gamra_Dariba-Harran-2010.xml
# 0 found / 0 in total
# Urfa-073_Talls_Flood-Harran-2010.xml done
# validating ../010_manannot/Urfa-073_Talls_Flood-Harran-2010.xml
# path:  ../010_manannot/Urfa-073_Talls_Flood-Harran-2010.xml
# 0 found / 0 in total
# Urfa-153_Sheikh_Hasan-Harran-2014.xml done
# validating ../010_manannot/Urfa-153_Sheikh_Hasan-Harran-2014.xml
# path:  ../010_manannot/Urfa-153_Sheikh_Hasan-Harran-2014.xml
# 0 found / 0 in total
# Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml done
# validating ../010_manannot/Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml
# path:  ../010_manannot/Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml
# 0 found / 0 in total
# Urfa-137_Kazan_Kebab-Harran-2013.xml done
# validating ../010_manannot/Urfa-137_Kazan_Kebab-Harran-2013.xml
# path:  ../010_manannot/Urfa-137_Kazan_Kebab-Harran-2013.xml
# 0 found / 0 in total
# Urfa-467_The_Big_Earthquake_of_February-Harran-2023.xml done
# validating ../010_manannot/Urfa-467_The_Big_Earthquake_of_February-Harran-2023.xml
# path:  ../010_manannot/Urfa-467_The_Big_Earthquake_of_February-Harran-2023.xml
# 0 found / 0 in total
# Urfa-195_Best_and_Worst_Part_of_the_Sheep-Harran-2017.xml done
# validating ../010_manannot/Urfa-195_Best_and_Worst_Part_of_the_Sheep-Harran-2017.xml
# path:  ../010_manannot/Urfa-195_Best_and_Worst_Part_of_the_Sheep-Harran-2017.xml
# 0 found / 0 in total
# Urfa-122_Nimrod-Harran-2010.xml done
# validating ../010_manannot/Urfa-122_Nimrod-Harran-2010.xml
# path:  ../010_manannot/Urfa-122_Nimrod-Harran-2010.xml
# 0 found / 0 in total
# Urfa-080_Gazelles_and_Jews-Harran-2010.xml done
# validating ../010_manannot/Urfa-080_Gazelles_and_Jews-Harran-2010.xml
# path:  ../010_manannot/Urfa-080_Gazelles_and_Jews-Harran-2010.xml
# 0 found / 0 in total
# Urfa-164_Baking_Bread-Harran-2014.xml done
# validating ../010_manannot/Urfa-164_Baking_Bread-Harran-2014.xml
# path:  ../010_manannot/Urfa-164_Baking_Bread-Harran-2014.xml
# 0 found / 0 in total
# Urfa-057_Story_of_Magician-Harran-2010.xml done
# validating ../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml
# path:  ../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml
# 0 found / 0 in total
# Urfa-201_Story_of_Cigkofte-Harran-2017.xml done
# validating ../010_manannot/Urfa-201_Story_of_Cigkofte-Harran-2017.xml
# path:  ../010_manannot/Urfa-201_Story_of_Cigkofte-Harran-2017.xml
# 0 found / 0 in total
# Urfa-167_Sheikh_Inad-Harran-2014.xml done
# validating ../010_manannot/Urfa-167_Sheikh_Inad-Harran-2014.xml
# path:  ../010_manannot/Urfa-167_Sheikh_Inad-Harran-2014.xml
# 0 found / 0 in total
# Urfa-068_Tribes_Armenians_Jews-Harran-2010.xml done
# validating ../010_manannot/Urfa-068_Tribes_Armenians_Jews-Harran-2010.xml
# path:  ../010_manannot/Urfa-068_Tribes_Armenians_Jews-Harran-2010.xml
# 0 found / 0 in total
# Urfa-048_Game_Cab-Harran-2010.xml done
# validating ../010_manannot/Urfa-048_Game_Cab-Harran-2010.xml
# path:  ../010_manannot/Urfa-048_Game_Cab-Harran-2010.xml
# 0 found / 0 in total
# Urfa-145_Prophet_Ayyub-Harran-2013.xml done
# validating ../010_manannot/Urfa-145_Prophet_Ayyub-Harran-2013.xml
# path:  ../010_manannot/Urfa-145_Prophet_Ayyub-Harran-2013.xml
# 0 found / 0 in total
# Urfa-191_Kurd_and_Two_Wives-Harran-2015.xml done
# validating ../010_manannot/Urfa-191_Kurd_and_Two_Wives-Harran-2015.xml
# path:  ../010_manannot/Urfa-191_Kurd_and_Two_Wives-Harran-2015.xml
# 0 found / 0 in total
# Urfa-032_Ali-Harran-2010.xml done
# validating ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# path:  ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# 0 found / 0 in total
# Urfa-140_Biyat-Harran-2013.xml done
# validating ../010_manannot/Urfa-140_Biyat-Harran-2013.xml
# path:  ../010_manannot/Urfa-140_Biyat-Harran-2013.xml
# 0 found / 0 in total
# Urfa-194_Afraid_of_Dogs-Harran-2017.xml done
# validating ../010_manannot/Urfa-194_Afraid_of_Dogs-Harran-2017.xml
# path:  ../010_manannot/Urfa-194_Afraid_of_Dogs-Harran-2017.xml
# 0 found / 0 in total
# Urfa-151_Ashura-Harran-2014.xml done
# validating ../010_manannot/Urfa-151_Ashura-Harran-2014.xml
# path:  ../010_manannot/Urfa-151_Ashura-Harran-2014.xml
# 0 found / 0 in total
# Urfa-173_Woman_with_No_Lover_Short-Harran-2014.xml done
# validating ../010_manannot/Urfa-173_Woman_with_No_Lover_Short-Harran-2014.xml
# path:  ../010_manannot/Urfa-173_Woman_with_No_Lover_Short-Harran-2014.xml
# 0 found / 0 in total
# Urfa-203_Tattooing-Harran-2017.xml done
# validating ../010_manannot/Urfa-203_Tattooing-Harran-2017.xml
# path:  ../010_manannot/Urfa-203_Tattooing-Harran-2017.xml
# 0 found / 0 in total
# Urfa-077c_The_Jinn-Harran-2010.xml done
# validating ../010_manannot/Urfa-077c_The_Jinn-Harran-2010.xml
# path:  ../010_manannot/Urfa-077c_The_Jinn-Harran-2010.xml
# 0 found / 0 in total
# Urfa-193_Priapism-Harran-2015.xml done
# validating ../010_manannot/Urfa-193_Priapism-Harran-2015.xml
# path:  ../010_manannot/Urfa-193_Priapism-Harran-2015.xml
# 0 found / 0 in total
# Urfa-188_Shepherd-Harran-2015.xml done
# validating ../010_manannot/Urfa-188_Shepherd-Harran-2015.xml
# path:  ../010_manannot/Urfa-188_Shepherd-Harran-2015.xml
# 0 found / 0 in total
# Urfa-125_Coffee-Harran-2010.xml done
# validating ../010_manannot/Urfa-125_Coffee-Harran-2010.xml
# path:  ../010_manannot/Urfa-125_Coffee-Harran-2010.xml
# 0 found / 0 in total
# Urfa-043_Truffle-Harran-2010.xml done
# validating ../010_manannot/Urfa-043_Truffle-Harran-2010.xml
# path:  ../010_manannot/Urfa-043_Truffle-Harran-2010.xml
# 0 found / 0 in total
# Urfa-002b_Blood_Feud_in_the_Past-Harran-2001.xml generated
# Urfa-428_How_Not_to_Get_Married_to_an_Old_Man-Harran-2022.xml done
# validating ../010_manannot/Urfa-428_How_Not_to_Get_Married_to_an_Old_Man-Harran-2022.xml
# path:  ../010_manannot/Urfa-428_How_Not_to_Get_Married_to_an_Old_Man-Harran-2022.xml
# 0 found / 0 in total
# Urfa-072_Villages-Harran-2010.xml done
# validating ../010_manannot/Urfa-072_Villages-Harran-2010.xml
# path:  ../010_manannot/Urfa-072_Villages-Harran-2010.xml
# 0 found / 0 in total
# Urfa-183_Policeman_and_Carp-Harran-2014.xml done
# validating ../010_manannot/Urfa-183_Policeman_and_Carp-Harran-2014.xml
# path:  ../010_manannot/Urfa-183_Policeman_and_Carp-Harran-2014.xml
# 0 found / 0 in total
# Urfa-027_Cultivation-Harran-2010.xml done
# validating ../010_manannot/Urfa-027_Cultivation-Harran-2010.xml
# path:  ../010_manannot/Urfa-027_Cultivation-Harran-2010.xml
# 0 found / 0 in total
# Urfa-149_Bird-Harran-2014.xml done
# validating ../010_manannot/Urfa-149_Bird-Harran-2014.xml
# path:  ../010_manannot/Urfa-149_Bird-Harran-2014.xml
# 0 found / 0 in total
# Urfa-176_Condolences-Harran-2014.xml done
# validating ../010_manannot/Urfa-176_Condolences-Harran-2014.xml
# path:  ../010_manannot/Urfa-176_Condolences-Harran-2014.xml
# 0 found / 0 in total
# Urfa-146_Wolf-Harran-2013.xml done
# validating ../010_manannot/Urfa-146_Wolf-Harran-2013.xml
# path:  ../010_manannot/Urfa-146_Wolf-Harran-2013.xml
# 0 found / 0 in total
# Urfa-069b_Arabicised_Kurds-Harran-2010.xml done
# validating ../010_manannot/Urfa-069b_Arabicised_Kurds-Harran-2010.xml
# path:  ../010_manannot/Urfa-069b_Arabicised_Kurds-Harran-2010.xml
# 0 found / 0 in total
# Urfa-177_Wedding_in_Former_Times-Harran-2014.xml done
# validating ../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml
# path:  ../010_manannot/Urfa-177_Wedding_in_Former_Times-Harran-2014.xml
# 0 found / 0 in total
# Urfa-107_Cotton_Business-Harran-2010.xml done
# validating ../010_manannot/Urfa-107_Cotton_Business-Harran-2010.xml
# path:  ../010_manannot/Urfa-107_Cotton_Business-Harran-2010.xml
# 0 found / 0 in total
# Urfa-133_Sheikh_Musa-Harran-2013.xml done
# validating ../010_manannot/Urfa-133_Sheikh_Musa-Harran-2013.xml
# path:  ../010_manannot/Urfa-133_Sheikh_Musa-Harran-2013.xml
# 0 found / 0 in total
# Urfa-087_Smide-Harran-2010.xml done
# validating ../010_manannot/Urfa-087_Smide-Harran-2010.xml
# path:  ../010_manannot/Urfa-087_Smide-Harran-2010.xml
# 0 found / 0 in total
# Urfa-135_Burglars_From_Syria-Harran-2013.xml done
# validating ../010_manannot/Urfa-135_Burglars_From_Syria-Harran-2013.xml
# path:  ../010_manannot/Urfa-135_Burglars_From_Syria-Harran-2013.xml
# 0 found / 0 in total
# Urfa-074_Talls_Burial_for_Children-Harran-2010.xml done
# validating ../010_manannot/Urfa-074_Talls_Burial_for_Children-Harran-2010.xml
# path:  ../010_manannot/Urfa-074_Talls_Burial_for_Children-Harran-2010.xml
# 0 found / 0 in total
# Urfa-355_Threshing_Wheat_in_Former_Times-Harran-2021.xml done
# validating ../010_manannot/Urfa-355_Threshing_Wheat_in_Former_Times-Harran-2021.xml
# path:  ../010_manannot/Urfa-355_Threshing_Wheat_in_Former_Times-Harran-2021.xml
# 0 found / 0 in total
# Urfa-076_Bedouins-Harran-2010.xml done
# validating ../010_manannot/Urfa-076_Bedouins-Harran-2010.xml
# path:  ../010_manannot/Urfa-076_Bedouins-Harran-2010.xml
# 0 found / 0 in total
# Urfa-070_Hen_House-Harran-2010.xml done
# validating ../010_manannot/Urfa-070_Hen_House-Harran-2010.xml
# path:  ../010_manannot/Urfa-070_Hen_House-Harran-2010.xml
# 0 found / 0 in total
# Urfa-000a_Namrud-Harran-2001.xml done
# validating ../010_manannot/Urfa-000a_Namrud-Harran-2001.xml
# path:  ../010_manannot/Urfa-000a_Namrud-Harran-2001.xml
# 0 found / 0 in total
# Urfa-141_Istishara-Harran-2013.xml done
# validating ../010_manannot/Urfa-141_Istishara-Harran-2013.xml
# path:  ../010_manannot/Urfa-141_Istishara-Harran-2013.xml
# 0 found / 0 in total
# Urfa-150_Iclikofte-Harran-2014.xml done
# validating ../010_manannot/Urfa-150_Iclikofte-Harran-2014.xml
# path:  ../010_manannot/Urfa-150_Iclikofte-Harran-2014.xml
# 0 found / 0 in total
# Urfa-047_Game_Qubbeya-Harran-2010.xml done
# validating ../010_manannot/Urfa-047_Game_Qubbeya-Harran-2010.xml
# path:  ../010_manannot/Urfa-047_Game_Qubbeya-Harran-2010.xml
# 0 found / 0 in total
# Urfa-155_Childhood-Harran-2014.xml done
# validating ../010_manannot/Urfa-155_Childhood-Harran-2014.xml
# path:  ../010_manannot/Urfa-155_Childhood-Harran-2014.xml
# 0 found / 0 in total
# Urfa-034_Liquorice-Harran-2010.xml done
# validating ../010_manannot/Urfa-034_Liquorice-Harran-2010.xml
# path:  ../010_manannot/Urfa-034_Liquorice-Harran-2010.xml
# 0 found / 0 in total
# Urfa-077a_The_Jinn-Harran-2010.xml done
# validating ../010_manannot/Urfa-077a_The_Jinn-Harran-2010.xml
# path:  ../010_manannot/Urfa-077a_The_Jinn-Harran-2010.xml
# 0 found / 0 in total
# Urfa-042_Hospitality-Harran-2010.xml done
# validating ../010_manannot/Urfa-042_Hospitality-Harran-2010.xml
# path:  ../010_manannot/Urfa-042_Hospitality-Harran-2010.xml
# 0 found / 0 in total
# Urfa-044_Sacks-Harran-2010.xml done
# validating ../010_manannot/Urfa-044_Sacks-Harran-2010.xml
# path:  ../010_manannot/Urfa-044_Sacks-Harran-2010.xml
# 0 found / 0 in total
# Urfa-124_Stealing_Boy_P2-Harran-2010.xml done
# validating ../010_manannot/Urfa-124_Stealing_Boy_P2-Harran-2010.xml
# path:  ../010_manannot/Urfa-124_Stealing_Boy_P2-Harran-2010.xml
# 0 found / 0 in total
# Urfa-077e_The_Jinn-Harran-2010.xml done
# validating ../010_manannot/Urfa-077e_The_Jinn-Harran-2010.xml
# path:  ../010_manannot/Urfa-077e_The_Jinn-Harran-2010.xml
# 0 found / 0 in total
# Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml done
# validating ../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml
# path:  ../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml
# 0 found / 0 in total
# Urfa-081_Food_in_Former_Times-Harran-2010.xml done
# validating ../010_manannot/Urfa-081_Food_in_Former_Times-Harran-2010.xml
# path:  ../010_manannot/Urfa-081_Food_in_Former_Times-Harran-2010.xml
# 0 found / 0 in total
# Urfa-123_Stealing_Boy_P1-Harran-2010.xml done
# validating ../010_manannot/Urfa-123_Stealing_Boy_P1-Harran-2010.xml
# path:  ../010_manannot/Urfa-123_Stealing_Boy_P1-Harran-2010.xml
# 0 found / 0 in total
# Urfa-061_Life_of_Harrani-Harran-2010.xml done
# validating ../010_manannot/Urfa-061_Life_of_Harrani-Harran-2010.xml
# path:  ../010_manannot/Urfa-061_Life_of_Harrani-Harran-2010.xml
# 0 found / 0 in total
# Urfa-187_Two_Women_and_Fridge-Harran-2015.xml done
# validating ../010_manannot/Urfa-187_Two_Women_and_Fridge-Harran-2015.xml
# path:  ../010_manannot/Urfa-187_Two_Women_and_Fridge-Harran-2015.xml
# 0 found / 0 in total
# Urfa-160_Seyhmus-Harran-2014.xml done
# validating ../010_manannot/Urfa-160_Seyhmus-Harran-2014.xml
# path:  ../010_manannot/Urfa-160_Seyhmus-Harran-2014.xml
# 0 found / 0 in total
# Urfa-069a_Armenians-Harran-2010.xml done
# validating ../010_manannot/Urfa-069a_Armenians-Harran-2010.xml
# path:  ../010_manannot/Urfa-069a_Armenians-Harran-2010.xml
# 0 found / 0 in total
# Urfa-192_Who_Chooses_a_Horse-Harran-2015.xml done
# validating ../010_manannot/Urfa-192_Who_Chooses_a_Horse-Harran-2015.xml
# path:  ../010_manannot/Urfa-192_Who_Chooses_a_Horse-Harran-2015.xml
# 0 found / 0 in total
# Urfa-012_Lentils-Harran-2010.xml done
# validating ../010_manannot/Urfa-012_Lentils-Harran-2010.xml
# path:  ../010_manannot/Urfa-012_Lentils-Harran-2010.xml
# 0 found / 0 in total
# Urfa-120_Cross_Marriage-Harran-2010.xml done
# validating ../010_manannot/Urfa-120_Cross_Marriage-Harran-2010.xml
# path:  ../010_manannot/Urfa-120_Cross_Marriage-Harran-2010.xml
# 0 found / 0 in total
# Urfa-077d_The_Jinn-Harran-2010.xml done
# validating ../010_manannot/Urfa-077d_The_Jinn-Harran-2010.xml
# path:  ../010_manannot/Urfa-077d_The_Jinn-Harran-2010.xml
# 0 found / 0 in total
# Urfa-139_Lahmacun-Harran-2013.xml done
# validating ../010_manannot/Urfa-139_Lahmacun-Harran-2013.xml
# path:  ../010_manannot/Urfa-139_Lahmacun-Harran-2013.xml
# 0 found / 0 in total
# Urfa-098_Young_Woman-Harran-2010.xml done
# validating ../010_manannot/Urfa-098_Young_Woman-Harran-2010.xml
# path:  ../010_manannot/Urfa-098_Young_Woman-Harran-2010.xml
# 0 found / 0 in total
# Urfa-119_Engagement-Harran-2010.xml done
# validating ../010_manannot/Urfa-119_Engagement-Harran-2010.xml
# path:  ../010_manannot/Urfa-119_Engagement-Harran-2010.xml
# 0 found / 0 in total
# Urfa-144_Malfuf-Harran-2013.xml done
# validating ../010_manannot/Urfa-144_Malfuf-Harran-2013.xml
# path:  ../010_manannot/Urfa-144_Malfuf-Harran-2013.xml
# 0 found / 0 in total
# Urfa-046_Game_Xwetime-Harran-2010.xml done
# validating ../010_manannot/Urfa-046_Game_Xwetime-Harran-2010.xml
# path:  ../010_manannot/Urfa-046_Game_Xwetime-Harran-2010.xml
# 0 found / 0 in total
# Urfa-115_Camel-Harran-2010.xml done
# validating ../010_manannot/Urfa-115_Camel-Harran-2010.xml
# path:  ../010_manannot/Urfa-115_Camel-Harran-2010.xml
# 0 found / 0 in total
# Urfa-112_Tall_Nasir-Harran-2010.xml done
# validating ../010_manannot/Urfa-112_Tall_Nasir-Harran-2010.xml
# path:  ../010_manannot/Urfa-112_Tall_Nasir-Harran-2010.xml
# 0 found / 0 in total
# Urfa-175_Bastig-Harran-2014.xml done
# validating ../010_manannot/Urfa-175_Bastig-Harran-2014.xml
# path:  ../010_manannot/Urfa-175_Bastig-Harran-2014.xml
# 0 found / 0 in total
# Urfa-033_Sheikh_Nifil-Harran-2010.xml done
# validating ../010_manannot/Urfa-033_Sheikh_Nifil-Harran-2010.xml
# path:  ../010_manannot/Urfa-033_Sheikh_Nifil-Harran-2010.xml
# 0 found / 0 in total
# Urfa-075_Corn_and_Language-Harran-2010.xml done
# validating ../010_manannot/Urfa-075_Corn_and_Language-Harran-2010.xml
# path:  ../010_manannot/Urfa-075_Corn_and_Language-Harran-2010.xml
# 0 found / 0 in total
# Urfa-002d_The_Bull_in_the_Jar-Harran-2001.xml done
# validating ../010_manannot/Urfa-002d_The_Bull_in_the_Jar-Harran-2001.xml
# path:  ../010_manannot/Urfa-002d_The_Bull_in_the_Jar-Harran-2001.xml
# 0 found / 0 in total
# Urfa-011_Cemetry-Harran-2010.xml done
# validating ../010_manannot/Urfa-011_Cemetry-Harran-2010.xml
# path:  ../010_manannot/Urfa-011_Cemetry-Harran-2010.xml
# 0 found / 0 in total
# Urfa-352_Washing_Clothes-Harran-2021.xml done
# validating ../010_manannot/Urfa-352_Washing_Clothes-Harran-2021.xml
# path:  ../010_manannot/Urfa-352_Washing_Clothes-Harran-2021.xml
# 0 found / 0 in total
# Urfa-054_Real_Friend-Harran-2010.xml done
# validating ../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml
# path:  ../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml
# 0 found / 0 in total
# Urfa-097_Three_Daughters-Harran-2010.xml done
# validating ../010_manannot/Urfa-097_Three_Daughters-Harran-2010.xml
# path:  ../010_manannot/Urfa-097_Three_Daughters-Harran-2010.xml
# 0 found / 0 in total
# Urfa-105_Life_in_Former_Times-Harran-2010.xml done
# validating ../010_manannot/Urfa-105_Life_in_Former_Times-Harran-2010.xml
# path:  ../010_manannot/Urfa-105_Life_in_Former_Times-Harran-2010.xml
# 0 found / 0 in total
# Urfa-014_Village_of_Qoran-Harran-2010.xml done
# validating ../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml
# path:  ../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml
# 0 found / 0 in total
# Urfa-094_Three_Advices-Harran-2010.xml done
# validating ../010_manannot/Urfa-094_Three_Advices-Harran-2010.xml
# path:  ../010_manannot/Urfa-094_Three_Advices-Harran-2010.xml
# 0 found / 0 in total
# Urfa-136_Cigkofte-Harran-2013.xml done
# validating ../010_manannot/Urfa-136_Cigkofte-Harran-2013.xml
# path:  ../010_manannot/Urfa-136_Cigkofte-Harran-2013.xml
# 0 found / 0 in total
# Urfa-002c_The_Incomplete_Meal-Harran-2001.xml done
# validating ../010_manannot/Urfa-002c_The_Incomplete_Meal-Harran-2001.xml
# path:  ../010_manannot/Urfa-002c_The_Incomplete_Meal-Harran-2001.xml
# 0 found / 0 in total
# Urfa-421b_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml generated
# Urfa-013_Snake_Killing-Harran-2010.xml done
# validating ../010_manannot/New/Urfa-013_Snake_Killing-Harran-2010.xml
# path:  ../010_manannot/New/Urfa-013_Snake_Killing-Harran-2010.xml
# 0 found / 0 in total
# Urfa-379c_Tribe_History-Harran-2022.xml done
# validating ../010_manannot/New/Urfa-379c_Tribe_History-Harran-2022.xml
# path:  ../010_manannot/New/Urfa-379c_Tribe_History-Harran-2022.xml
# 0 found / 0 in total
# Urfa-196_What_the_Aunt_Thinks_of_her_Two_Husbands-Harran-2017.xml done
# validating ../010_manannot/New/Urfa-196_What_the_Aunt_Thinks_of_her_Two_Husbands-Harran-2017.xml
# path:  ../010_manannot/New/Urfa-196_What_the_Aunt_Thinks_of_her_Two_Husbands-Harran-2017.xml
# 0 found / 0 in total
# Urfa-206_Agriculture_in_Former_Times-Harran-2017.xml done
# validating ../010_manannot/New/Urfa-206_Agriculture_in_Former_Times-Harran-2017.xml
# path:  ../010_manannot/New/Urfa-206_Agriculture_in_Former_Times-Harran-2017.xml
# 0 found / 0 in total
# Urfa-416_Mezra_on_Conflict-Harran-2022.xml done
# validating ../010_manannot/New/Urfa-416_Mezra_on_Conflict-Harran-2022.xml
# path:  ../010_manannot/New/Urfa-416_Mezra_on_Conflict-Harran-2022.xml
# 0 found / 2 in total
# Urfa-540_Amine_Bastard-Harran-2024.xml generated
# Urfa-197_Slaughtering_and_Plucking_the_Chicken-Harran-2017.xml done
# validating ../010_manannot/New/Urfa-197_Slaughtering_and_Plucking_the_Chicken-Harran-2017.xml
# path:  ../010_manannot/New/Urfa-197_Slaughtering_and_Plucking_the_Chicken-Harran-2017.xml
# 0 found / 2 in total
# Urfa-463_Family_Story-Harran-2023.xml generated
# Urfa-379d_Tribe_History-Harran-2022.xml done
# validating ../010_manannot/New/Urfa-379d_Tribe_History-Harran-2022.xml
# path:  ../010_manannot/New/Urfa-379d_Tribe_History-Harran-2022.xml
# 0 found / 2 in total
# Urfa-438a_Conversations-Harran-2023.xml generated
# Urfa-519_Man_and_Meat-Harran-2024.xml generated
# Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml done
# validating ../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml
# path:  ../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml
# 0 found / 21 in total
# Urfa-207b_Wedding_Death_Clothes_in_Former_Times-Harran-2017.xml done
# validating ../010_manannot/New/Urfa-207b_Wedding_Death_Clothes_in_Former_Times-Harran-2017.xml
# path:  ../010_manannot/New/Urfa-207b_Wedding_Death_Clothes_in_Former_Times-Harran-2017.xml
# 0 found / 21 in total
# Urfa-548_Cemile_Cige-Harran-2024.xml generated
# Urfa-379b_Tribe_History-Harran-2022.xml done
# validating ../010_manannot/New/Urfa-379b_Tribe_History-Harran-2022.xml
# path:  ../010_manannot/New/Urfa-379b_Tribe_History-Harran-2022.xml
# 0 found / 21 in total
# Urfa-089_Pasha-Harran-2010.xml done
# validating ../010_manannot/New/Urfa-089_Pasha-Harran-2010.xml
# path:  ../010_manannot/New/Urfa-089_Pasha-Harran-2010.xml
# 0 found / 21 in total
# Urfa-478_Story-Harran-2023.xml generated
# Urfa-430_Sheikhs_Prophet_Ibrahim-Harran-2022.xml generated
# Urfa-172_Working_in_Gas_Station-Harran-2014.xml done
# validating ../010_manannot/New/Urfa-172_Working_in_Gas_Station-Harran-2014.xml
# path:  ../010_manannot/New/Urfa-172_Working_in_Gas_Station-Harran-2014.xml
# 0 found / 21 in total
# Urfa-549_Cemile_Besh_Tash-Harran-2024.xml generated
# Urfa-379e_Tribe_History-Harran-2022.xml done
# validating ../010_manannot/New/Urfa-379e_Tribe_History-Harran-2022.xml
# path:  ../010_manannot/New/Urfa-379e_Tribe_History-Harran-2022.xml
# 0 found / 21 in total
# Urfa-198_Eid_alAdha-Harran-2017.xml done
# validating ../010_manannot/New/Urfa-198_Eid_alAdha-Harran-2017.xml
# path:  ../010_manannot/New/Urfa-198_Eid_alAdha-Harran-2017.xml
# 0 found / 21 in total
# Urfa-180_Diseases_in_Former_Times-Harran-2014.xml done
# validating ../010_manannot/New/Urfa-180_Diseases_in_Former_Times-Harran-2014.xml
# path:  ../010_manannot/New/Urfa-180_Diseases_in_Former_Times-Harran-2014.xml
# 0 found / 21 in total
# Urfa-382_Bani_Ashur-Harran-2022.xml done
# validating ../010_manannot/New/Urfa-382_Bani_Ashur-Harran-2022.xml
# path:  ../010_manannot/New/Urfa-382_Bani_Ashur-Harran-2022.xml
# 0 found / 21 in total
# Urfa-598_Excuse_Bahane-Harran-2025.xml generated
# Urfa-415_Mezra_Jail_Story-Harran-2022.xml done
# validating ../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml
# path:  ../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml
# 0 found / 84 in total
# Urfa-143_Burgul-Harran-2013.xml done
# validating ../010_manannot/New/Urfa-143_Burgul-Harran-2013.xml
# path:  ../010_manannot/New/Urfa-143_Burgul-Harran-2013.xml
# 0 found / 84 in total
# Urfa-051_Fatima-Harran-2010.xml done
# validating ../010_manannot/New/Urfa-051_Fatima-Harran-2010.xml
# path:  ../010_manannot/New/Urfa-051_Fatima-Harran-2010.xml
# 0 found / 84 in total
# Urfa-310_Conversation_in_front_of_the_House_Part4-Harran-2018.xml done
# validating ../010_manannot/New/Urfa-310_Conversation_in_front_of_the_House_Part4-Harran-2018.xml
# path:  ../010_manannot/New/Urfa-310_Conversation_in_front_of_the_House_Part4-Harran-2018.xml
# 0 found / 84 in total
# Urfa-185_Sneezing-Harran-2015.xml done
# validating ../010_manannot/New/Urfa-185_Sneezing-Harran-2015.xml
# path:  ../010_manannot/New/Urfa-185_Sneezing-Harran-2015.xml
# 0 found / 84 in total
# Urfa-205_Second_Marriage-Harran-2017.xml done
# validating ../010_manannot/New/Urfa-205_Second_Marriage-Harran-2017.xml
# path:  ../010_manannot/New/Urfa-205_Second_Marriage-Harran-2017.xml
# 0 found / 84 in total
# Urfa-460_Waterwell-Harran-2023.xml generated
# Urfa-207a_Wedding_Death_Clothes_in_Former_Times-Harran-2017.xml done
# validating ../010_manannot/New/Urfa-207a_Wedding_Death_Clothes_in_Former_Times-Harran-2017.xml
# path:  ../010_manannot/New/Urfa-207a_Wedding_Death_Clothes_in_Former_Times-Harran-2017.xml
# 0 found / 84 in total
# Urfa-539_Amine_Doctor_Story-Harran-2024.xml generated
# Urfa-600_Cradle-Harran-2025.xml generated
# Urfa-200_Burying_Grandfather-Harran-2017.xml done
# validating ../010_manannot/New/Urfa-200_Burying_Grandfather-Harran-2017.xml
# path:  ../010_manannot/New/Urfa-200_Burying_Grandfather-Harran-2017.xml
# 0 found / 84 in total
# Urfa-204_Water_Hose-Harran-2017.xml done
# validating ../010_manannot/New/Urfa-204_Water_Hose-Harran-2017.xml
# path:  ../010_manannot/New/Urfa-204_Water_Hose-Harran-2017.xml
# 0 found / 84 in total
# Urfa-379a_Tribe_History-Harran-2022.xml done
# validating ../010_manannot/New/Urfa-379a_Tribe_History-Harran-2022.xml
# path:  ../010_manannot/New/Urfa-379a_Tribe_History-Harran-2022.xml
# 0 found / 84 in total
# Urfa-526_Selfpride-Harran-2024.xml generated
# Urfa-438b_Conversations-Harran-2023.xml generated
# Urfa-443_Arabs_and_Kurds-Harran-2023.xml generated
# Urfa-366_Conversation_and_Second_Wife-Harran-2021.xml done
# validating ../010_manannot/New/Urfa-366_Conversation_and_Second_Wife-Harran-2021.xml
# path:  ../010_manannot/New/Urfa-366_Conversation_and_Second_Wife-Harran-2021.xml
# 0 found / 84 in total
# Urfa-546_Amine_Grandmother_Soldiers-Harran-2024.xml generated
# Urfa-509_Personal_Story-Harran-2023.xml generated

# %%
validationErrors
# Out:
# [{'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 159,
#   'source': '../010_manannot/New/Urfa-416_Mezra_on_Conflict-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 217,
#   'source': '../010_manannot/New/Urfa-416_Mezra_on_Conflict-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[6]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 231,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 262,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[5]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 289,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[7]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 304,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[9]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 329,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[12]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 358,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[15]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 397,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[17]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 416,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[19]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 447,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[21]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 489,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[24]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 509,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[25]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 548,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[27]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 578,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[29]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 609,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[31]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 643,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[34]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 676,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[36]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 697,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[38]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 719,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[40]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 746,
#   'source': '../010_manannot/New/Urfa-421a_Kontorcus_Sheikhs_Crododile_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[42]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 537,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[2]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 557,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[4]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 611,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[8]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 649,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[11]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 655,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[12]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 669,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[14]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 684,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[16]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 710,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[18]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 765,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[21]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 798,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[24]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 861,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[28]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 896,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[30]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 931,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[32]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 960,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[34]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 990,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[36]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1012,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[38]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1048,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[41]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1088,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[44]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1118,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[47]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1186,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[51]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1224,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[53]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1241,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[55]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1311,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[58]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1365,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[62]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1381,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[64]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1414,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[66]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1461,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[69]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1479,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[71]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1496,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[72]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1527,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[75]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1576,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[78]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1708,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[84]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1745,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[87]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1789,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[90]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1849,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[94]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1876,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[96]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 1987,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[103]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2095,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[109]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2135,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[112]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2202,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[116]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2259,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[120]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2298,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[123]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2442,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[130]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2511,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[134]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2558,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[137]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2601,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[140]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2629,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[143]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2636,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[144]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2733,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[150]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2758,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[152]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2856,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[157]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2938,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[162]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 2964,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[164]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 3046,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[168]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 3079,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[170]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 3099,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[172]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 3144,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[175]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 3204,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[178]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 3221,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[180]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 3255,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[183]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 3314,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[187]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 3398,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[192]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'},
#  {'type': 'error',
#   'message': "The 'who' attribute of u must point to a person defined in the\n                                    header",
#   'line': 3445,
#   'source': '../010_manannot/New/Urfa-415_Mezra_Jail_Story-Harran-2022.xml',
#   'entry': '',
#   'relativePath': '',
#   'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:div[195]/tei:u[1]',
#   'stage': 'schematron',
#   'exceptionType': 'failed-assert'}]

# %%
validation_no_err_begin = """
<!DOCTYPE html>
<html>
<head>
<meta charset="UTF-8">
<style>
body {
    margin: 0;
    height: 100vh;
    display: flex;
    justify-content: center;   /* horizontal centering */
    align-items: center;       /* vertical centering */
    background: #f9fafb;       /* soft background (optional) */
    font-family: "Segoe UI", Roboto, sans-serif;
}

.center-message {
    font-size: 1.5rem;
    color: #333;
    padding: 1rem 2rem;
    background: #ffffff;
    border-radius: 12px;
    box-shadow: 0 4px 16px rgba(0,0,0,0.08);
}
</style>
"""

# %%
validation_css_begin = """
<!DOCTYPE html>
<html>
<head>
<meta charset="UTF-8">

<style>
table {
    font-family: Arial, sans-serif;
    font-size: 13px;
    border-collapse: collapse;
    width: 100%;
}
th, td {
    border: 1px solid #ccc;
    padding: 6px;
    text-align: left;
}
thead {
    background: #eee;
}
</style>

</head>
<script>
function filterTable() {
    const input = document.getElementById("tableFilter");
    const filter = input.value.toLowerCase();
    const table = document.getElementById("myTable");
    const rows = table.getElementsByTagName("tr");

    for (let i = 1; i < rows.length; i++) {  // skip header (row 0)
        let rowText = rows[i].innerText.toLowerCase();
        rows[i].style.display = rowText.includes(filter) ? "" : "none";
    }
}
</script>
<body>
<input
    type="text"
    id="tableFilter"
    placeholder="Type to filter..."
    onkeyup="filterTable()"
    style="
        padding: 5px 10px;
        margin-bottom: 5px;
        width: 100%;
        max-width: 400px;
        font-size: 14px;
        border: 1px solid #ccc;
        border-radius: 8px;
        box-shadow: 1px 1px 4px rgba(0,0,0,0.1);
        outline: none;
        transition: border 0.2s;
    "
    onfocus="this.style.border='1px solid #007acc';"
    onblur="this.style.border='1px solid #ccc';"
/>
"""

# %%
validation_end = """
</body>
</html>
"""

# %%
def make_clickable(source, line=None):
    link = source.replace('../','https://github.dev/acdh-oeaw/shawi-data/blob/main/') if source.endswith("dc_shawi_eng.xml") else source.replace('../','https://github.com/acdh-oeaw/shawi-data/tree/main/')
    if line:
        return f'<a href="{link}#L{line}">{source}</a>'
    else:
        return f'<a href="{link}">{source}</a>'

# %%
def make_entry_clickable(source, entry):
    link = source.split("/")[-1]
    if entry:
        return f'<a href="{link}#{entry}">{entry}</a>'
    else:
        return '' # so that not "None" is shown

# %%
if len(ignoredFiles) > 0:
    df_ignored = pd.DataFrame(data=ignoredFiles).T
    df_ignored = df_ignored.transpose()
    df_ignored
    ignoredReport = "tmp/ignoredFiles.html"
    df_ignored['link'] = df_ignored.apply(lambda x: make_clickable(x['source']), axis=1)

    with open(ignoredReport, 'w', encoding='utf-8') as f:
        f.write(df_ignored.to_html(render_links=True, escape=False))

# %%
errorReport = "tmp/validationReport.html"
dictErrorReport = "tmp/dictValidationReport.html"

# %%
def no_validation_error(report):
    with open(report, 'w', encoding='utf-8') as f:
        f.write(validation_no_err_begin)
        f.write('<p class="center-message">No validation errors found.</p>')
        f.write(validation_end)

# %%
if len(validationErrors) > 0:
    df_err = pd.DataFrame(data=validationErrors).T
    df_err = df_err.transpose()
    print(f"found {len(validationErrors)} validation errors")
    df_err['link'] = df_err.apply(lambda x: make_clickable(x['source'], x['line']), axis=1)
    if "entry" in df_err.columns:
        df_err.drop(columns=["entry"], inplace=True)
    if "relativePath" in df_err.columns:
        df_err.drop(columns=["relativePath"], inplace=True)
    with open(errorReport, 'w', encoding='utf-8') as f:
        f.write(validation_css_begin)
        f.write(df_err.to_html(render_links=True, escape=False, table_id="myTable"))
        f.write(validation_end)
else:
    no_validation_error(errorReport)
# Out:
# found 84 validation errors

# %%
#df_err

# %%
if len(dictValidationErrors) > 0:
    df_err = pd.DataFrame(data=dictValidationErrors).T
    df_err = df_err.transpose()
    print(f"found {len(dictValidationErrors)} dictionary validation errors")
    df_err['entry'] = df_err.apply(lambda x: make_entry_clickable(x['source'], x['entry']), axis=1)
    df_err['link'] = df_err.apply(lambda x: make_clickable(x['source'], x['line']), axis=1)
    if "source" in df_err.columns:
        df_err.drop(columns=["source"], inplace=True)
    with open(dictErrorReport, 'w', encoding='utf-8') as f:
        f.write(validation_css_begin)
        f.write(df_err.to_html(render_links=True, escape=False, table_id="myTable"))
        f.write(validation_end)
else:
    no_validation_error(dictErrorReport)
# Out:
# found 16 dictionary validation errors

# %% [markdown]
# ### create and style html page

# %%
index_css = """
    <style>
        body {
            font-family: Arial, sans-serif;
            background: #f4f4f4;
            padding: 40px;
        }
        .card {
            background: #ffffff;
            padding: 20px;
            margin: 15px 0;
            border-radius: 10px;
            box-shadow: 0px 2px 6px rgba(0,0,0,0.1);
            transition: 0.2s;
        }
        .card:hover {
            transform: scale(1.02);
        }
        .card-link {
            text-decoration: none;
            color: #333;
        }
        .card-link h2 {
            margin: 0;
        }
    </style>
"""

# %%
pages = [
    ("manannot_validation.html", "manannot"),
    ("dict_validation.html", "dictionary")
]

html = """
<!DOCTYPE html>
<html>
<head>
    <meta charset="UTF-8">
    <title>Index</title>
"""
html += index_css
html += """
</head>
<body>
    <h1>Shawi Validation Reports</h1>
    <ul>
"""

for filename, title in pages:
    html += f'''
        <div class="card">
            <a class="card-link" href="{filename}">
                <h2>{title}</h2>
            </a>
        </div>
    '''

html += """
</ul>
</body>
</html>
"""

with open("tmp/index.html", "w") as f:
    f.write(html)
