# %% [markdown]
# # Validating finished Shawi Corpus Files
#
# * Install & set up dependencies
# * extract schematron from RNG and transform to XSLT
# * run schematron-xslt on files

# %%
import io
import os
import requests
import pathlib
import re
import sys
import json
import pandas as pd
import linecache as lc
import shutil

from pathlib import Path
from urllib.parse import urlsplit
import saxonche
from zipfile import ZipFile
from lxml import isoschematron, etree

# %%
tmpDir = "tmp"
libDir = "lib"
os.makedirs(tmpDir, exist_ok=True)
os.makedirs(libDir, exist_ok=True)
nss = {"tei":"http://www.tei-c.org/ns/1.0"}
# the root of the git repository
dataHome = ".."

# rng schema
rngSchema = dataHome + "/main/802_tei_odd/out/shawi_corpus.rng"
# the path to the annotated TEI transcription files
manannot = dataHome + "/main/010_manannot"

# include those documents in validation which have the following status in //tei:revisionDesc/@status / ignore all others
VALIDATE_DOCS_WITH_STATUS = "done"

with saxonche.PySaxonProcessor(license=False) as proc:
# SaxonC 1.2.1 Python has many known bugs but isn't maintained anymore
# Many of the documented API specs are not working
    print(proc.version)
    proc.set_cwd(os.path.dirname(os.path.abspath('')))
    print(proc.cwd)
# Out:
# SaxonC-HE 12.4 from Saxonica
# C:\Users\mrauschsupola\Shawi\shawi-data

# %%
def downloadAndStore(url, force=False):   
    #  filename of the file to be downloaded
    fn = os.path.basename(url)
    # fn w/o extension
    basename = os.path.splitext(fn)[0]
    # extension 
    ext = os.path.splitext(fn)[1]
    dlFilePath = tmpDir + "/" + fn
    if not os.path.exists(dlFilePath) and not force == True:
        payload = requests.get(url).content
        open(dlFilePath, 'wb').write(payload)
    return dlFilePath

# %%
def downloadAndUnzip(url):    
    #  filename of the file to be downloaded
    fn = os.path.basename(url)
    # fn w/o extension
    basename = os.path.splitext(fn)[0]
    # extension 
    ext = os.path.splitext(fn)[1]
    
    if ext != ".zip":
        return "not a zip archive"
    else:
        zipFilePath = downloadAndStore(url)
        # the path where the content should be extracted to
        targetPath = libDir + "/" + basename
        
        
        payload = requests.get(url).content
        open(zipFilePath, 'wb').write(payload)
        ZipFile(zipFilePath).extractall(path=targetPath)
    
    return targetPath

# %% [markdown]
# ### Install XSL based schematron validator

# %%
_schCompiler = None
def setupSchXSLT():
    global _schCompiler
    if _schCompiler is not None:
        return _schCompiler
    schDLURL = "https://github.com/schxslt/schxslt/releases/download/v1.9.5/schxslt-1.9.5-xslt-only.zip"
    schHome = downloadAndUnzip(schDLURL)
    _schCompiler = schHome + "/schxslt-1.9.5/2.0/pipeline-for-svrl.xsl"
    if os.path.exists(_schCompiler):
        return _schCompiler
    else: 
        print("error: something went wrong, cannot locate file '" + schCompiler + "'")

# %%
setupSchXSLT()
# Out:
# 'lib/schxslt-1.9.5-xslt-only/schxslt-1.9.5/2.0/pipeline-for-svrl.xsl'

# %%
def transform(s, xsl, o, parameters=[]):
    # processor keeps files open on Windows and in doing so prevents moving or copying them
    with saxonche.PySaxonProcessor(license=False) as proc:
        proc.set_configuration_property("xi", "on")
        saxon = proc.new_xslt30_processor()
        for i in parameters:
            saxon.set_parameter(name=i, value=proc.make_string_value(parameters[i]))
        exec = saxon.compile_stylesheet(stylesheet_file=os.path.abspath(xsl))
        exec.apply_templates_returning_file(source_file=os.path.abspath(s), output_file=os.path.abspath(o))
        if exec.exception_occurred:
            exec.get_error_message
            #for i in range(saxon.exception_count()-1):
            print(saxon.get_error_message())
            print(os.path.abspath(s)+" - "+os.path.abspath(xsl)+" -> "+os.path.abspath(o)+" failed")
        if os.path.exists(os.path.abspath(o)):
            return o
        else: 
            print("there was an error transforming "+s+" with stylesheet "+xsl)

# %%
def extractSchematron(rng):
    """extracts a schematron document embedded in an rng schema"""
    print("extracting Schematron document from "+rng)
    rng2sch = setupRNG2Sch()
    sch = tmpDir + "/" + os.path.basename(rng) + ".sch"
    if not os.path.exists(sch):
        transform(rng, rng2sch, sch)
    return sch

# %%
def compileSchematron(sch):
    """compiles a schematron document to an XSLT stylesheet"""
    outputPath = tmpDir + "/" + os.path.basename(sch) + ".xsl"
    schCompiler = setupSchXSLT()
    
    transform(sch, schCompiler, outputPath)
    if os.path.exists(outputPath):
        return outputPath
    else: 
        print("error: something went wrong, cannot locate file '" + outputPath + "'")

# %% [markdown]
# ## Prepare rng2sch stylesheet
#
# Returns path to the xsl that extracts schematron form the RelaxNG schema.
# This should only run once as the file gets locked (by saxon) and so further attempts to pring it to the correct location will fail.

# %%
_rng2sch = None 
def setupRNG2Sch():
    global _rng2sch
    if _rng2sch is not None:
        return _rng2sch
    RNG2SchtrDL = "https://raw.githubusercontent.com/Schematron/schematron/master/trunk/converters/code/ToSchematron/ExtractSchFromRNG.xsl"
    dltmp = downloadAndStore(RNG2SchtrDL)
    # tweak XSLT 
    with open(dltmp, encoding='utf-8') as inputfile:
        lines = inputfile.read()
    lines = lines.replace( 'http://www.ascc.net/xml/schematron','http://purl.oclc.org/dsdl/schematron/')
    lines = lines.replace( '<sch:schema','<sch:schema queryBinding="xslt2"')
    
    with open(dltmp, 'w', encoding='utf-8') as file:
        file.writelines(lines)
    _rng2sch = libDir+"/"+os.path.basename(dltmp)
    os.replace(dltmp, _rng2sch)
    if os.path.exists(_rng2sch):
        return _rng2sch
    else:
        print("error: something went wrong, cannot locate file '" + newPath + "'")

# %%
setupRNG2Sch()
# Out:
# 'lib/ExtractSchFromRNG.xsl'

# %%
def schValidate(sch, path):
    """validates a document (at path) against schematron schema (at sch)"""
    errs = []
    out = tmpDir + "/validationReports/" + os.path.basename(path)
    xsl = compileSchematron(sch)
    try:
        transform(path, xsl, out)

    except saxonche.PySaxonApiError as e:
        # We swallow parsing errors here as they should have been reported by lxml already
        print("an error occured while running schValidate on "+path)
        return []
    
    report = etree.parse(out)
    successfulReport = report.findall("{http://purl.oclc.org/dsdl/svrl}successful-report")
    failedAssert = report.findall("{http://purl.oclc.org/dsdl/svrl}failed-assert")
    doc = etree.parse(path)
    for s in successfulReport + failedAssert:
        XPath = s.attrib['location'].replace('Q{http://www.tei-c.org/ns/1.0}','tei:').replace('Q{}','')
        # DEBUG
        node = doc.xpath(XPath, namespaces=nss)[0]
        if type(node) is etree._ElementUnicodeResult:
            elt = node.getparent()
        else:
            elt = node

        msg = s.find("{http://purl.oclc.org/dsdl/svrl}text").text

        errObj = {
            "type" : "error",
            "message":  msg,
            "line" : elt.sourceline,
            "source": path,
            "location": XPath,
            #"text": elt.text, #checking text values (for @lemmaRef)
            "stage": "schematron",
            "exceptionType": str(s.tag).replace("{http://purl.oclc.org/dsdl/svrl}",""),
        }
        
        errs.append(errObj)
    return errs

# %%
def validate(path, rngSchema):
    """Validate a document against the rngSchema. Returns a list of dicts of which each one represents a validation (or parsing) error."""
    validationErrors = []
    sch = extractSchematron(rngSchema)
    shutil.copyfile(sch, '../802_tei_odd/out/'+os.path.basename(sch)) #copy file from tmp folder into odd folder to be able to git it
    try:
        doc = etree.parse(path)
    
        # relaxng validation
        relaxng_doc = etree.parse(rngSchema)
        relaxng = etree.RelaxNG(relaxng_doc)
        relaxng.assertValid(doc)
        
        # schematron validation
        schErrs = schValidate(sch, path)
        if len(schErrs) >= 1:
            validationErrors = validationErrors + schErrs
    
    except etree.XMLSyntaxError as e:
        valErrObj = {
            "type" : "error",
            "message": str(e), 
            "line": e.lineno,
            "source": path, 
            "location": "n/a",
            "stage" : "parsing", 
            "exceptionType": type(e).__name__
        }
        return valErrObj
        
    except etree.DocumentInvalid as e:
        for error in e.error_log:
            # we ignore rng errors about @schemaLocation since 
            # that is needed for validation in the TEI-enricher
            if error.message != "Invalid attribute schemaLocation for element TEI":
                location = "n/a" if error.path is None else error.path
                valErrObj = {
                    "type" : "error",
                    "message": error.message, 
                    "line": error.line, 
                    "source": path, 
                    "location": location,
                    "stage" : "relaxng", 
                    "exceptionType": type(e).__name__
                }
                # DEBUG
                print(valErrObj)
                validationErrors.append(valErrObj)
        
        # if the document is invalid against the RNG, we still want to run schematron against it
        schErrs = schValidate(sch, path)
        if len(schErrs) >= 1:
            validationErrors = validationErrors + schErrs
        
        
    
    return validationErrors

# %%
validationErrors = []
ignoredFiles = []

# %%
def docStatus(path):
    """returns the status of the document at path; if the document can't be parsed, it returns a dict with the error"""
    try:
        doc = etree.parse(path)
        revisionDesc = doc.xpath("/tei:TEI/tei:teiHeader/tei:revisionDesc", namespaces=nss)[0]
        status = revisionDesc.attrib['status']
        return status
    # report documents which are not well-formed
    except etree.XMLSyntaxError as e:
        print(e)

# %%
for i in os.scandir(manannot):
    if i.name.startswith('Urfa') and i.name.endswith('.xml') and i.is_file():
        filename = os.path.basename(i)
        filepath = manannot + "/" + filename
        status = docStatus(filepath)
        print(filename, status)
        
        # if the document is not finished yet (//tei:revisionDesc/@status != DOCSTATUS_DONE), just ignore it
        if type(status) is str and status != VALIDATE_DOCS_WITH_STATUS:
            ignoredFiles.append({
                "source" : filepath,
                "type" : "ignored",
                "status": status
            })
        # if the document couldn't be parsed, docStatus() returns a dict 
        # with some error information which is appended to the list of 
        # validation errors
        elif type(status) is dict and status["type"] == "error":
            validationErrors.append(status) 
        
        # … otherwise try to validate the document
        else:
            print("validating " + filepath)
            results = validate(filepath, rngSchema)
            print(results)
            len(results)
            if type(results) is list:
                res_errs = filter(lambda x: x['type'] == "error", results)
                res_ignored = filter(lambda x: x['type'] == "ignored", results)
                validationErrors = validationErrors + list(res_errs)
                print(f"{len(list(res_errs))} found / {len(validationErrors)} in total")
            elif type(results) is dict:
                if results['type'] == "ignored":
                    ignoredFiles.append(results)
            else:
                print("unknown result type")
                print(results)
# Out:
# Urfa-000_Cigkofte-Harran-2001.xml generated
# Urfa-002_1_Joke_about_a_tribe.xml done
# validating ../010_manannot/Urfa-002_1_Joke_about_a_tribe.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Element span has extra content: text', 'line': 398, 'source': '../010_manannot/Urfa-002_1_Joke_about_a_tribe.xml', 'location': '/*/*[2]/*[2]/*/*[7]/*[2]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Element span has extra content: text', 'line': 398, 'source': '../010_manannot/Urfa-002_1_Joke_about_a_tribe.xml', 'location': '/*/*[2]/*[2]/*/*[7]/*[2]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}]
# 0 found / 1 in total
# Urfa-002_2_Blood_feud_in_the_past.xml generated
# Urfa-002_3_The-incomplete_meal.xml generated
# Urfa-002_4_The_bull_in_the_jar.xml generated
# Urfa-011_Cemetry-Harran-2010.xml done
# validating ../010_manannot/Urfa-011_Cemetry-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 1 in total
# Urfa-012_Lentils-Harran-2010.xml done
# validating ../010_manannot/Urfa-012_Lentils-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 1 in total
# Urfa-014_Village_of_Qoran-Harran-2010.xml done
# validating ../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Element w failed to validate attributes', 'line': 1250, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[19]/*[1]/*[41]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Element w failed to validate attributes', 'line': 1250, 'source': '../010_manannot/Urfa-014_Village_of_Qoran-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[19]/*[1]/*[41]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}]
# 0 found / 2 in total
# Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml done
# validating ../010_manannot/Urfa-024a_Vegetabels_and_Seasonal_Work-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 2 in total
# Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml done
# validating ../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.aslan_000'", 'line': 1525, 'source': '../010_manannot/Urfa-024b_Vegetabels_and_Seasonal_Work-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[22]/tei:u[1]/tei:w[17]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 3 in total
# Urfa-027_Cultivation-Harran-2010.xml done
# validating ../010_manannot/Urfa-027_Cultivation-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 3 in total
# Urfa-029_Smoking-Harran-2010.xml done
# validating ../010_manannot/Urfa-029_Smoking-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 3 in total
# Urfa-032_Ali-Harran-2010.xml done
# validating ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Element span has extra content: text', 'line': 329, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[3]/*[2]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# {'type': 'error', 'message': 'Element span has extra content: text', 'line': 972, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[20]/*[2]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# {'type': 'error', 'message': 'Element span has extra content: text', 'line': 1040, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[22]/*[2]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# {'type': 'error', 'message': 'Element span has extra content: text', 'line': 1080, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[23]/*[2]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# {'type': 'error', 'message': 'Element w failed to validate attributes', 'line': 1668, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[40]/*[1]/*[22]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# {'type': 'error', 'message': 'Element w failed to validate attributes', 'line': 1673, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[40]/*[1]/*[27]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Element span has extra content: text', 'line': 329, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[3]/*[2]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'Element span has extra content: text', 'line': 972, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[20]/*[2]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'Element span has extra content: text', 'line': 1040, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[22]/*[2]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'Element span has extra content: text', 'line': 1080, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[23]/*[2]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'Element w failed to validate attributes', 'line': 1668, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[40]/*[1]/*[22]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': 'Element w failed to validate attributes', 'line': 1673, 'source': '../010_manannot/Urfa-032_Ali-Harran-2010.xml', 'location': '/*/*[2]/*[2]/*/*[40]/*[1]/*[27]', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}]
# 0 found / 9 in total
# Urfa-033_Sheikh_Nifil-Harran-2010.xml done
# validating ../010_manannot/Urfa-033_Sheikh_Nifil-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 9 in total
# Urfa-034_Liquorice-Harran-2010.xml done
# validating ../010_manannot/Urfa-034_Liquorice-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 9 in total
# Urfa-042_Hospitality-Harran-2010.xml done
# validating ../010_manannot/Urfa-042_Hospitality-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 9 in total
# Urfa-043_Truffle-Harran-2010.xml done
# validating ../010_manannot/Urfa-043_Truffle-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 9 in total
# Urfa-044_Sacks-Harran-2010.xml done
# validating ../010_manannot/Urfa-044_Sacks-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 9 in total
# Urfa-045_Gamra_Dariba-Harran-2010.xml done
# validating ../010_manannot/Urfa-045_Gamra_Dariba-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 9 in total
# Urfa-046_Game_Xwetime-Harran-2010.xml done
# validating ../010_manannot/Urfa-046_Game_Xwetime-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 9 in total
# Urfa-047_Game_Qubbeya-Harran-2010.xml done
# validating ../010_manannot/Urfa-047_Game_Qubbeya-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 9 in total
# Urfa-048_Game_Cab-Harran-2010.xml done
# validating ../010_manannot/Urfa-048_Game_Cab-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# []
# 0 found / 9 in total
# Urfa-054_Real_Friend-Harran-2010.xml done
# validating ../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# {'type': 'error', 'message': 'Invalid attribute when for element change', 'line': 134, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/*/*[1]/*[4]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}
# [{'type': 'error', 'message': 'Invalid attribute when for element change', 'line': 134, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/*/*[1]/*[4]/*', 'stage': 'relaxng', 'exceptionType': 'DocumentInvalid'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.hagiigi_000'", 'line': 320, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[4]/tei:u[1]/tei:w[10]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.xaam_001'", 'line': 380, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[6]/tei:u[1]/tei:w[9]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.gahannam_000'", 'line': 485, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[9]/tei:u[1]/tei:w[12]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.muuse_000'", 'line': 520, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[10]/tei:u[1]/tei:w[7]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.yardem_000'", 'line': 802, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[18]/tei:u[1]/tei:w[25]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.pulusi_000'", 'line': 993, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[24]/tei:u[1]/tei:w[6]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.cjattaf_000'", 'line': 1044, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[25]/tei:u[1]/tei:w[9]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.ifaade_000'", 'line': 1086, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[26]/tei:u[1]/tei:w[20]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.pulusi_000'", 'line': 1145, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[28]/tei:u[1]/tei:w[4]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.xaam_001'", 'line': 1181, 'source': '../010_manannot/Urfa-054_Real_Friend-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[29]/tei:u[1]/tei:w[6]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.darras_000'", 'line': 1195, 'source': ' ...
# 0 found / 22 in total
# Urfa-057_Story_of_Magician-Harran-2010.xml done
# validating ../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml
# extracting Schematron document from ../802_tei_odd/out/shawi_corpus.rng
# [{'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.baashe_000'", 'line': 182, 'source': '../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[1]/tei:u[1]/tei:w[6]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.qaaymaqaam_000'", 'line': 346, 'source': '../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[2]/tei:u[1]/tei:w[68]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.shihat_000'", 'line': 522, 'source': '../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[4]/tei:u[1]/tei:w[34]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.sarr_001'", 'line': 678, 'source': '../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[6]/tei:u[1]/tei:w[46]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.mahrame_000'", 'line': 679, 'source': '../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[6]/tei:u[1]/tei:w[47]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.geraz_000'", 'line': 747, 'source': '../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[7]/tei:u[1]/tei:w[25]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}, {'type': 'error', 'message': "There is no entry in the dictionary for the current w element: 'dict:DShaAr.xabar_001'", 'line': 867, 'source': '../010_manannot/Urfa-057_Story_of_Magician-Harran-2010.xml', 'location': '/tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]/tei:annotationBlock[9]/tei:u[1]/tei:w[26]', 'stage': 'schematron', 'exceptionType': 'failed-assert'}]
# 0 found / 29 in total
# Urfa-061_Life_of_al-Harrani-Harran-2010.xml draft
# Urfa-068_Tribes_Armenians_Jews-Harran-2010.xml draft
# Urfa-069a_Armenians-Harran-2010.xml draft
# Urfa-069b_Arabicised_Kurds-Harran-2010.pfsx.xml draft
# Urfa-070_Hen_House-Harran-2010.xml draft
# Urfa-072_Villages-Harran-2010.xml draft
# Urfa-073_Talls_Flood-Harran-2010.xml draft
# Urfa-074_Talls_Burial_for_Children-Harran-2010.xml draft
# Urfa-075_Corn_and_Language-Harran-2010.xml draft
# Urfa-076_Bedouins-Harran-2010.xml draft
# Urfa-077a_The_Jinn-Harran-2010.xml draft
# Urfa-077b_The_Jinn-Harran-2010.xml draft
# Urfa-077c_The_Jinn-Harran-2010.xml draft
# Urfa-077d_The_Jinn-Harran-2010.xml draft
# Urfa-077e_The_Jinn-Harran-2010.xml draft
# Urfa-080_Gazelles_and_Jews-Harran-2010.xml draft
# Urfa-081_Food_in_Former_Times-Harran-2010.xml draft
# Urfa-085_The_Snake_in_the_Cistern-Harran-2010.xml draft
# Urfa-087_Smide-Harran-2010.xml draft
# Urfa-092_Sultan_Murad-Harran-2010.xml draft
# Urfa-094_Three_Advices-Harran-2010.xml draft
# Urfa-097_Three_Daughters-Harran-2010.xml draft
# Urfa-098_Young_Woman-Harran-2010.xml draft
# Urfa-105_Life_in_Former_Times-Harran-2010.xml draft
# Urfa-106_Visa_in_Ankara-Harran-2010.xml draft
# Urfa-107_Cotton_Business-Harran-2010.xml draft
# Urfa-110_Salim_az-Zir-Harran-2010.xml draft
# Urfa-112_Tall_Nasir-Harran-2010.xml draft
# Urfa-115_Camel-Harran-2010.xml draft
# Urfa-119_Engagement-Harran-2010.xml draft
# Urfa-120_Cross_Marriage-Harran-2010.xml draft
# Urfa-122_Nimrod-Harran-2010.xml draft
# Urfa-123_Stealing_Boy_P1-Harran-2010.xml draft
# Urfa-124_Stealing_Boy_P2-Harran-2010.xml draft
# Urfa-125_Coffee-Harran-2010.xml draft
# Urfa-133_Sheikh_Musa-Harran-2013.xml draft
# Urfa-135_Burglars_From_Syria-Harran-2013.xml draft
# Urfa-136_Cigkofte-Harran-2013.xml draft
# Urfa-137_Kazan_Kebab-Harran-2013.xml generated
# Urfa-138_Kazan_Kebab-Harran-2013.xml generated
# Urfa-139_Lahmacun-Harran-2013.xml draft
# Urfa-140_Biyat-Harran-2013.xml draft
# Urfa-141_Istishara-Harran-2013.xml generated
# Urfa-142_Chilli_Pepper-Harran-2013.xml draft
# Urfa-144_Malfuf-Harran-2013.xml draft
# Urfa-145_Prophet_Ayyub-Harran-2013.xml generated
# Urfa-146_Wolf-Harran-2013.xml generated
# Urfa-149_Bird-Harran-2014.xml generated
# Urfa-150_Iclikofte-Harran-2014.xml draft
# Urfa-151_Ashura-Harran-2014.xml draft
# Urfa-152_Dream-Harran-2014.xml draft
# Urfa-153_Sheikh_Hasan-Harran-2014.xml draft
# Urfa-155_Childhood-Harran-2014.xml draft
# Urfa-158_Moses_and_Dog-Harran-2014.xml draft
# Urfa-160_Seyhmus-Harran-2014.xml draft
# Urfa-162_Umm_al-Qet-Harran-2014.xml draft
# Urfa-163_Quilts-Harran-2014.xml draft
# Urfa-164_Baking_Bread-Harran-2014.xml draft
# Urfa-165_Childhood-Harran-2014.xml generated
# Urfa-167_Sheikh_'Nad-Harran-2014.xml draft
# Urfa-173_Woman_with_No_Lover_Short-Harran-2014.xml draft
# Urfa-175_Bastig-Harran-2014.xml draft
# Urfa-176_Condolences-Harran-2014.xml draft
# Urfa-177_Wedding_in_Former_Times-Harran-2014.xml generated
# Urfa-179_Grandfather-Harran-2014.xml generated
# Urfa-183_Policeman_and_Carp-Harran-2014.xml draft
# Urfa-184_Evil_Eye-Harran-2014.xml draft
# Urfa-187_Two_Women_and_Fridge-Harran-2015.xml draft
# Urfa-188_Shepherd-Harran-2015.xml generated
# Urfa-189_Wanted_to_Marry-Harran.xml generated
# Urfa-190_ill_Blind_Mother-Harran-2015.xml generated
# Urfa-191_Kurd_and_Two_Wives-Harran-2015.xml generated
# Urfa-192_Who_chooses_a_horse-Harran.xml generated
# Urfa-193_Priapism-Harran-2015.xml generated
# Urfa-194_Afraid_of_Dogs-Harran-2017.xml generated
# Urfa-195_Best_and_Worst_Part_of_the_Sheep-Harran-2017.xml generated
# Urfa-201_Story_of_Cigkofte-Harran-2017.xml generated
# Urfa-202_Al-Shukwa-Harran-2017.xml generated
# Urfa-203_Tattooing-Harran-2017.xml generated
# Urfa-352_Washing_Clothes-Harran-2021.xml generated
# Urfa-355_Threshing_wheat_in_former_times.xml generated
# Urfa-428_How_not_to_get_married_to_an_old_man.xml generated
# Urfa-467_The_big_earthquake_of_February_2023.xml generated

# %%
def make_clickable(source, line=None):
    link = source.replace('../','https://github.com/acdh-oeaw/shawi-data/tree/main/')
    if line:
        return f'<a href="{link}#L{line}">{source}</a>'
    else:
        return f'<a href="{link}">{source}</a>'

# %%
if len(ignoredFiles) > 0:
    df_ignored = pd.DataFrame(data=ignoredFiles).T
    df_ignored = df_ignored.transpose()
    df_ignored
    ignoredReport = "tmp/ignoredFiles.html"
    df_ignored['link'] = df_ignored.apply(lambda x: make_clickable(x['source']), axis=1)

    with open(ignoredReport, 'w', encoding='utf-8') as f:
        f.write(df_ignored.to_html(render_links=True, escape=False))

# %%
if len(validationErrors) > 0:
    df_err = pd.DataFrame(data=validationErrors).T
    df_err = df_err.transpose()
    df_err
    print(f"found {len(validationErrors)} validation errors")
    #df_err = df_err[df_err["message"].str.contains("@lemmaRef is required when xml:lang is 'ar-acm")==False]
    #df_err = df_err[df_err["message"].str.contains("There is no entry in the dictionary for the")==True]
    errorReport = "tmp/validationReport.html"
    df_err['link'] = df_err.apply(lambda x: make_clickable(x['source'], x['line']), axis=1)
    with open(errorReport, 'w', encoding='utf-8') as f:
        f.write(df_err.to_html(render_links=True, escape=False))
# Out:
# found 29 validation errors

# %%
df_err
# Out:
#      type                                            message  line  \
# 0   error               Element span has extra content: text   398
# 1   error            Element w failed to validate attributes  1250
# 2   error  There is no entry in the dictionary for the cu...  1525
# 3   error               Element span has extra content: text   329
# 4   error               Element span has extra content: text   972
# 5   error               Element span has extra content: text  1040
# 6   error               Element span has extra content: text  1080
# 7   error            Element w failed to validate attributes  1668
# 8   error            Element w failed to validate attributes  1673
# 9   error          Invalid attribute when for element change   134
# 10  error  There is no entry in the dictionary for the cu...   320
# 11  error  There is no entry in the dictionary for the cu...   380
# 12  error  There is no entry in the dictionary for the cu...   485
# 13  error  There is no entry in the dictionary for the cu...   520
# 14  error  There is no entry in the dictionary for the cu...   802
# 15  error  There is no entry in the dictionary for the cu...   993
# 16  error  There is no entry in the dictionary for the cu...  1044
# 17  error  There is no entry in the dictionary for the cu...  1086
# 18  error  There is no entry in the dictionary for the cu...  1145
# 19  error  There is no entry in the dictionary for the cu...  1181
# 20  error  There is no entry in the dictionary for the cu...  1195
# 21  error  There is no entry in the dictionary for the cu...  1248
# 22  error  There is no entry in the dictionary for the cu...   182
# 23  error  There is no entry in the dictionary for the cu...   346
# 24  error  There is no entry in the dictionary for the cu...   522
# 25  error  There is no entry in the dictionary for the cu...   678
# 26  error  There is no entry in the dictionary for the cu...   679
# 27  error  There is no entry in the dictionary for the cu...   747
# 28  error  There is no entry in the dictionary for the cu...   867
#
#                                                source  \
# 0   ../010_manannot/Urfa-002_1_Joke_about_a_tribe.xml
# 1   ../010_manannot/Urfa-014_Village_of_Qoran-Harr...
# 2   ../010_manannot/Urfa-024b_Vegetabels_and_Seaso...
# 3        ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# 4        ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# 5        ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# 6        ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# 7        ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# 8        ../010_manannot/Urfa-032_Ali-Harran-2010.xml
# 9   ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 10  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 11  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 12  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 13  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 14  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 15  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 16  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 17  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 18  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 19  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 20  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 21  ../010_manannot/Urfa-054_Real_Friend-Harran-20...
# 22  ../010_manannot/Urfa-057_Story_of_Magician-Har...
# 23  ../010_manannot/Urfa-057_Story_of_Magician-Har...
# 24  ../010_manannot/Urfa-057_Story_of_Magician-Har...
# 25  ../010_manannot/Urfa-057_Story_of_Magician-Har...
# 26  ../010_manannot/Urfa-057_Story_of_Magician-Har...
# 27  ../010_manannot/Urfa-057_Story_of_Magician-Har...
# 28  ../010_manannot/Urfa-057_Story_of_Magician-Har...
#
#                                              location       stage  \
# 0                          /*/*[2]/*[2]/*/*[7]/*[2]/*     relaxng
# 1                     /*/*[2]/*[2]/*/*[19]/*[1]/*[41]     relaxng
# 2   /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 3                          /*/*[2]/*[2]/*/*[3]/*[2]/*     relaxng
# 4                         /*/*[2]/*[2]/*/*[20]/*[2]/*     relaxng
# 5                         /*/*[2]/*[2]/*/*[22]/*[2]/*     relaxng
# 6                         /*/*[2]/*[2]/*/*[23]/*[2]/*     relaxng
# 7                     /*/*[2]/*[2]/*/*[40]/*[1]/*[22]     relaxng
# 8                     /*/*[2]/*[2]/*/*[40]/*[1]/*[27]     relaxng
# 9                                      /*/*[1]/*[4]/*     relaxng
# 10  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 11  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 12  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 13  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 14  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 15  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 16  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 17  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 18  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 19  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 20  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 21  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 22  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 23  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 24  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 25  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 26  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 27  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
# 28  /tei:TEI[1]/tei:text[1]/tei:body[1]/tei:div[1]...  schematron
#
#       exceptionType                                               link
# 0   DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# 1   DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# 2     failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 3   DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# 4   DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# 5   DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# 6   DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# 7   DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# 8   DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# 9   DocumentInvalid  <a href="https://github.com/acdh-oeaw/shawi-da...
# 10    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 11    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 12    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 13    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 14    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 15    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 16    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 17    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 18    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 19    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 20    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 21    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 22    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 23    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 24    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 25    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 26    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 27    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
# 28    failed-assert  <a href="https://github.com/acdh-oeaw/shawi-da...
